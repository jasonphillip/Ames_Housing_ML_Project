# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import statsmodels.api as sm

# the below extension properly formats a cell after it is run
# %load_ext nb_black
pd.set_option("display.max_columns", 800)

# Set the maximum number of rows to 200
pd.set_option("display.max_rows", 200)


# Set the maximum number of columns to 200
pd.set_option("display.max_columns", 200)
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
housing = pd.read_csv("../data/housing_no_na.csv", index_col=0)
housing
# Out:
#            GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# PID
# 909176150        856     126000          30       RL         -1.0     7890
# 905476230       1049     139500         120       RL         42.0     4235
# 911128020       1001     124900          30  C (all)         60.0     6060
# 535377150       1039     114000          70       RL         80.0     8146
# 534177230       1665     227000          60       RL         70.0     8400
# ...              ...        ...         ...      ...          ...      ...
# 903205040        952     121000          30       RL         -1.0     8854
# 905402060       1733     139600          20       RL         -1.0    13680
# 909275030       2002     145000          90       RH         82.0     6270
# 907192040       1842     217500          60       RL         -1.0     8826
# 906223180       1911     215000          60       RL         80.0     9554
#
#           Street     Alley LotShape LandContour Utilities LotConfig LandSlope  \
# PID
# 909176150   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 905476230   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 911128020   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 535377150   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 534177230   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# ...          ...       ...      ...         ...       ...       ...       ...
# 903205040   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905402060   Pave  No_Alley      IR1         Lvl    AllPub   CulDSac       Gtl
# 909275030   Pave  No_Alley      Reg         HLS    AllPub    Inside       Gtl
# 907192040   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 906223180   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl
#
#           Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# PID
# 909176150        SWISU       Norm       Norm     1Fam     1Story            6
# 905476230      Edwards       Norm       Norm   TwnhsE     1Story            5
# 911128020       IDOTRR       Norm       Norm     1Fam     1Story            5
# 535377150      OldTown       Norm       Norm     1Fam     2Story            4
# 534177230       NWAmes       Norm       Norm     1Fam     2Story            8
# ...                ...        ...        ...      ...        ...          ...
# 903205040      BrkSide       Norm       Norm     1Fam     1.5Unf            6
# 905402060      Edwards       Norm       Norm     1Fam     1Story            3
# 909275030      Crawfor       Norm       Norm   Duplex     2Story            5
# 907192040      CollgCr       Norm       Norm     1Fam     2Story            7
# 906223180      SawyerW       Norm       Norm     1Fam     2Story            8
#
#            OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# PID
# 909176150            6       1939          1950     Gable  CompShg
# 905476230            5       1984          1984     Gable  CompShg
# 911128020            9       1930          2007       Hip  CompShg
# 535377150            8       1900          2003     Gable  CompShg
# 534177230            6       2001          2001     Gable  CompShg
# ...                ...        ...           ...       ...      ...
# 903205040            6       1916          1950     Gable  CompShg
# 905402060            5       1955          1955       Hip  CompShg
# 909275030            6       1949          1950     Gable  CompShg
# 907192040            5       2000          2000     Gable  CompShg
# 906223180            5       1993          1994     Gable  CompShg
#
#           Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# PID
# 909176150     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 905476230     HdBoard     HdBoard    BrkFace       149.0        Gd        TA
# 911128020     MetalSd     MetalSd       None         0.0        Gd        TA
# 535377150     MetalSd     MetalSd       None         0.0        Gd        Gd
# 534177230     VinylSd     VinylSd       None         0.0        Gd        TA
# ...               ...         ...        ...         ...       ...       ...
# 903205040     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 905402060     BrkFace     Wd Sdng       None         0.0        TA        TA
# 909275030     MetalSd     MetalSd       None         0.0        TA        TA
# 907192040     VinylSd     VinylSd    BrkFace       144.0        Gd        TA
# 906223180     VinylSd     VinylSd    BrkFace       125.0        Gd        TA
#
#           Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# PID
# 909176150     CBlock       TA       TA           No          Rec       238.0
# 905476230     CBlock       Gd       TA           Mn          GLQ       552.0
# 911128020     BrkTil       TA       TA           No          ALQ       737.0
# 535377150     BrkTil       Fa       TA           No          Unf         0.0
# 534177230      PConc       Gd       TA           No          GLQ       643.0
# ...              ...      ...      ...          ...          ...         ...
# 903205040     BrkTil       TA       TA           No          Unf         0.0
# 905402060       Slab  No_Bsmt  No_Bsmt      No_Bsmt      No_Bsmt         0.0
# 909275030     CBlock       TA       TA           No          BLQ       284.0
# 907192040      PConc       Gd       TA           No          GLQ       841.0
# 906223180      PConc       Gd       TA           No          GLQ       380.0
#
#           BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# PID
# 909176150          Unf         0.0      618.0        856.0    GasA        TA
# 905476230          ALQ       393.0      104.0       1049.0    GasA        TA
# 911128020          Unf         0.0      100.0        837.0    GasA        Ex
# 535377150          Unf         0.0      405.0        405.0    GasA        Gd
# 534177230          Unf         0.0      167.0        810.0    GasA        Ex
# ...                ...         ...        ...          ...     ...       ...
# 903205040          Unf         0.0      952.0        952.0    Grav        Fa
# 905402060      No_Bsmt         0.0        0.0          0.0    GasA        Ex
# 909275030          Unf         0.0      717.0       1001.0    GasA        TA
# 907192040          Unf         0.0      144.0        985.0    GasA        Ex
# 906223180          Unf         0.0      397.0        777.0    GasA        Ex
#
#           CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# PID
# 909176150          Y      SBrkr       856         0             0
# 905476230          Y      SBrkr      1049         0             0
# 911128020          Y      SBrkr      1001         0             0
# 535377150          Y      SBrkr       717       322             0
# 534177230          Y      SBrkr       810       855             0
# ...              ...        ...       ...       ...           ...
# 903205040          N      FuseF       952         0             0
# 905402060          Y      FuseA      1733         0             0
# 909275030          N      FuseA      1001      1001             0
# 907192040          Y      SBrkr       985       857             0
# 906223180          Y      SBrkr      1065       846             0
#
#            BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# PID
# 909176150           1.0           0.0         1         0             2
# 905476230           1.0           0.0         2         0             2
# 911128020           0.0           0.0         1         0             2
# 535377150           0.0           0.0         1         0             2
# 534177230           1.0           0.0         2         1             3
# ...                 ...           ...       ...       ...           ...
# 903205040           0.0           0.0         1         0             2
# 905402060           0.0           0.0         2         0             4
# 909275030           0.0           0.0         2         0             4
# 907192040           1.0           0.0         2         1             3
# 906223180           0.0           0.0         2         1             3
#
#            KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# PID
# 909176150             1          TA             4        Typ           1
# 905476230             1          Gd             5        Typ           0
# 911128020             1          Gd             5        Typ           0
# 535377150             1          TA             6        Typ           0
# 534177230             1          Gd             6        Typ           0
# ...                 ...         ...           ...        ...         ...
# 903205040             1          Fa             4        Typ           1
# 905402060             1          TA             8       Min2           1
# 909275030             2          TA             8        Typ           0
# 907192040             1          Gd             7        Typ           1
# 906223180             1          Gd             8        Typ           1
#
#             FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# PID
# 909176150            Gd     Detchd       1939.0          Unf         2.0
# 905476230  No_Fireplace     Attchd       1984.0          Fin         1.0
# 911128020  No_Fireplace     Detchd       1930.0          Unf         1.0
# 535377150  No_Fireplace     Detchd       1940.0          Unf         1.0
# 534177230  No_Fireplace     Attchd       2001.0          Fin         2.0
# ...                 ...        ...          ...          ...         ...
# 903205040            Gd     Detchd       1916.0          Unf         1.0
# 905402060            Gd     Attchd       1955.0          Unf         2.0
# 909275030  No_Fireplace     2Types       1949.0          Unf         3.0
# 907192040            TA     Attchd       2000.0          Fin         2.0
# 906223180            TA     Attchd       1993.0          RFn         2.0
#
#            GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  \
# PID
# 909176150       399.0         TA         TA          Y           0
# 905476230       266.0         TA         TA          Y           0
# 911128020       216.0         TA         Po          N         154
# 535377150       281.0         TA         TA          N           0
# 534177230       528.0         TA         TA          Y           0
# ...               ...        ...        ...        ...         ...
# 903205040       192.0         Fa         Po          P           0
# 905402060       452.0         TA         TA          Y           0
# 909275030       871.0         TA         TA          Y           0
# 907192040       486.0         TA         TA          Y         193
# 906223180       471.0         TA         TA          Y         182
#
#            OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# PID
# 909176150            0              0          0          166         0
# 905476230          105              0          0            0         0
# 911128020            0             42         86            0         0
# 535377150            0            168          0          111         0
# 534177230           45              0          0            0         0
# ...                ...            ...        ...          ...       ...
# 903205040           98              0          0           40         0
# 905402060            0              0          0            0         0
# 909275030            0              0          0            0         0
# 907192040           96              0          0            0         0
# 906223180           81              0          0            0         0
#
#             PoolQC     Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# PID
# 909176150  No_Pool  No_Fence        None        0       3    2010      WD
# 905476230  No_Pool  No_Fence        None        0       2    2009      WD
# 911128020  No_Pool  No_Fence        None        0      11    2007      WD
# 535377150  No_Pool  No_Fence        None        0       5    2009      WD
# 534177230  No_Pool  No_Fence        None        0      11    2009      WD
# ...            ...       ...         ...      ...     ...     ...      ...
# 903205040  No_Pool  No_Fence        None        0       5    2009      WD
# 905402060  No_Pool  No_Fence        None        0       6    2009      WD
# 909275030  No_Pool  No_Fence        None        0       8    2007      WD
# 907192040  No_Pool  No_Fence        None        0       7    2007      WD
# 906223180  No_Pool  No_Fence        None        0       9    2006      WD
#
#           SaleCondition
# PID
# 909176150        Normal
# 905476230        Normal
# 911128020        Normal
# 535377150        Normal
# 534177230        Normal
# ...                 ...
# 903205040        Normal
# 905402060        Normal
# 909275030        Normal
# 907192040        Normal
# 906223180        Normal
#
# [2580 rows x 80 columns]

# %%
housing_no_na = pd.read_csv("data/housing_no_na.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 housing_no_na = pd.read_csv("data/housing_no_na.csv")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/housing_no_na.csv'

# %%
locations = pd.read_csv("../data/locations.csv")
locations
# Use the loc accessor to filter the dataframe on the PID column
locations
# Out:
#       Unnamed: 0        PID  SalePrice Neighborhood  \
# 0              0  909176150     126000        SWISU
# 1              1  905476230     139500      Edwards
# 2              2  905476230     139500      Edwards
# 3              3  911128020     124900       IDOTRR
# 4              4  535377150     114000      OldTown
# ...          ...        ...        ...          ...
# 2599        2599  903205040     121000      BrkSide
# 2600        2600  905402060     139600      Edwards
# 2601        2601  909275030     145000      Crawfor
# 2602        2602  907192040     217500      CollgCr
# 2603        2603  906223180     215000      SawyerW
#
#                            Prop_Addr   latitude  longitude
# 0         436 HAYWARD AVE, AMES, USA  42.018564 -93.651619
# 1            3416 WEST ST, AMES, USA  42.024855 -93.663671
# 2            3416 WEST ST, AMES, USA  42.024855 -93.663671
# 3            320 S 2ND ST, AMES, USA  42.021548 -93.614068
# 4        1524 DOUGLAS AVE, AMES, USA  42.037391 -93.612207
# ...                              ...        ...        ...
# 2599   1021 RIDGEWOOD AVE, AMES, USA  42.032102 -93.626373
# 2600        3619 MARY CIR, AMES, USA  42.027669 -93.666138
# 2601  2140 SUNSET DR 2142, AMES, USA  42.020129 -93.643832
# 2602    5319 CLEMENS BLVD, AMES, USA  42.016802 -93.689748
# 2603      1025 VERMONT CT, AMES, USA  42.030997 -93.682220
#
# [2604 rows x 7 columns]

# %%
cols_to_check = [col for col in housing.columns if "Gara" in col]

# Filter the dataframe to only include rows where GarageYrBlt is -1
filtered_housing = housing[housing["GarageYrBlt"] == -1]

# Use value_counts() to count the values for each column in the filtered dataframe
for col in cols_to_check:
    print(filtered_housing[col].value_counts())
# Out:
# No_Garage    127
# Detchd         2
# Name: GarageType, dtype: int64
# -1.0    129
# Name: GarageYrBlt, dtype: int64
# No_Garage    129
# Name: GarageFinish, dtype: int64
# 0.0    128
# 1.0      1
# Name: GarageCars, dtype: int64
# 0.0      128
# 360.0      1
# Name: GarageArea, dtype: int64
# No_Garage    129
# Name: GarageQual, dtype: int64
# No_Garage    129
# Name: GarageCond, dtype: int64

# %%
filtered_housing.sort_values(by='GarageCars', ascending=False)
# Out:
#            GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# PID
# 903426160       1984     160000          60       RM         57.0     8094
# 909101060        864      67000          30       RL         45.0     8248
# 903225050        784     109500          45       RM         50.0     6130
# 903456090        754      84500         190       RM         60.0     6780
# 535376010        882     103200          45       RL         55.0     5500
# 903476090       1864      97500         190       RM         41.0     5852
# 909250030       1666     100000          50       RL         51.0     9839
# 923228420        630      81000         180       RM         21.0     1890
# 909101180       1716     135900         190       RL         55.0     5687
# 923400125        970     132000          85       RL         62.0    10441
# 902104060       1140      96500          50       RM         55.0     8800
# 910202050        796      55000          30       RM         40.0     3636
# 531363040       1143     147000          20       RL         63.0     7500
# 531375050       1175     146000          20       RL         63.0    13072
# 903476100        840      87000          45       RM         55.0     4388
# 902331010        816      58500          30  C (all)         -1.0     3300
# 534276360       1225     128950          20       RL         77.0     9320
# 535383100       1294     106250         190       RL         60.0    10800
# 908250040       1137      96000          50       RL         57.0     8050
# 903430130        693      52500          30       RM        153.0     4118
# 902109080       1594     118000         190       RM         63.0    11426
# 534450150        708      82500          30       RL         50.0     5330
# 907135180        990     123600          20       RL         60.0     8070
# 909100170        864      98000          30       RL         67.0     5604
# 527403120        858      88000          20       RL         -1.0     8125
# 534451150       1306      76500          30       RL         55.0     5350
# 908127120        996     108000          30       RL         63.0    13907
# 534451170        729      52000          30       RL         56.0     4130
# 911225110        936      78000          50  C (all)         60.0     8520
# 923228290        630      84500         180       RM         21.0     1936
# 531375090       1114     142000          20       RL         63.0    13072
# 535353160       1544     138000          50       RL         60.0    14190
# 902306120       1540     129400          70       RM         60.0     6000
# 527401160       1792     136000          90       RL         60.0     9000
# 532378130        912     124000          20       RL         -1.0     8020
# 904351280       1355     127500         190       RL         62.0    10106
# 905101310       1768     136500          90       RL         72.0    10778
# 904101070       3086     200500          50       RL        138.0    18030
# 923204150       1824     139000          90       RL         94.0     9400
# 534450110        666      64500          20       RL         50.0     5000
# 923226250       1092      76000         160       RM         21.0     1476
# 905477010       1124      93000          20       RL         77.0     8335
# 910203090       1200     119000          50       RM         58.0     8155
# 908275040       1678     119900          90       RL         65.0    10926
# 905426030       1518     260000          30       RL         85.0    19550
# 903454060       1092      55000         190       RM         70.0     5600
# 905477050       1347     107500         190       RL         70.0     7000
# 903232170        912      80500          50       RM         52.0     6240
# 902134120       1447     103000          50       RM         56.0    10134
# 531363050       1158     143500          20       RL         63.0     7500
# 923275140        833     112000          20       RL         -1.0     8780
# 902328040       1484     128000          75       RM         35.0     6300
# 903426200       1560     159900          70       RM         60.0    12900
# 535457040       1800     141000          90       RL         80.0     8000
# 903231060        800      60000          30       RM         51.0     6120
# 911103060       1991     119600         190  C (all)         75.0     8250
# 905200160       1006      80000          20       RL         -1.0     9000
# 902109130       1701      94550         190       RM         63.0     7627
# 909177100       2650     160000          90       RH         60.0     7200
# 908102030        796      85000          30       RL         67.0     8777
# 905452070        864      99600          90       RL         50.0     9350
# 905101100       1020      94000          50       RL         54.0     6342
# 531363060       1080     141000          20       RL         63.0     7500
# 908130020        914     117250          20       RL         75.0     8050
# 907200230       1040     124000          20       RL         60.0     8430
# 903481100       1344      82375         190       RM         60.0    10320
# 923228080       1092      98000         160       RM         21.0     1477
# 908201040        698     118000          20       RL         50.0     9405
# 908103310       1012     127500          90       RL         38.0     7840
# 903458110       1406      89500          50       RM         -1.0     7920
# 527425090        864     115000          20       RL         70.0    10500
# 910201050       1601     129850          50       RM         50.0     7288
# 905101300       1832     136000          90       RL         72.0    10773
# 923228150       1344      97000         160       RM         21.0     1533
# 902330010       2358     122000          70       RM         50.0     5250
# 910201180       1828     150909          70       RM         50.0     9060
# 908203100        960      90000          20       RL         64.0     6410
# 908226180        774      79000          30       RH         70.0     4270
# 902128075       1027     120000          30       RM         60.0     5400
# 908204180       1152      61500          90       RL         74.0     6882
# 535456050       1800     130000          90       RL        113.0     8513
# 923400150        974      93500          20       RL         63.0    10712
# 902477120        720      34900          30  C (all)         60.0     7879
# 534451020        670      64000          50       RL         51.0     3500
# 909250210       1522     102000          50       RL         60.0     6000
# 905228050        660      63900          20       RL         -1.0     9000
# 911175440       1396     115000         190  C (all)         50.0     9000
# 903454010       1355     127000          70       RM         60.0     6882
# 923226320        630      75500         180       RM         21.0     1491
# 923226180        630      73000         180       RM         21.0     1470
# 908201120       1440     118000          90       RL         92.0    12108
# 910203100        672      72000          30       RM         61.0     8534
# 904301060       1200     179000          90       RL         60.0    10800
# 909176170       2592     150000          90       RL         60.0    10890
# 902106130        936     109500          30       RM         56.0     4485
# 535379110       1534     148000          70       RL         60.0    10800
# 908204160       1152      82500          90       RL         74.0     6845
# 923230120        796     138000          85       RL         50.0     6723
# 908102040       2200     145900          90       RL         67.0     8777
# 908127100        816     118500          90       RL         81.0    11841
# 923228220       1092      93900         160       RM         21.0     1495
# 902456015       1020      64500          50  C (all)         63.0     4761
# 904302260       1392     100000         190       RL         60.0     9900
# 535456010       1556     119000          90       RL         75.0     8512
# 902105060       1464     129000          70       RM         90.0     9900
# 923228260       1092      90500         160       RM         21.0     1936
# 908102130       1664     100000          90       RL         75.0     9825
# 904301375        904      61000          30       RL         -1.0    10020
# 905480150       1096      79000          50       RL         60.0     9600
# 909131125       1928     160000         190       RH         -1.0     7082
# 534451120        869      85500          30       RL         51.0     5900
# 534450180        858     116500          20       RL         50.0     7207
# 535383060        599      59000          30       RL         90.0     5400
# 905476170        605      86000          30       RL         58.0     9098
# 908225170        784      91900         190       RL         56.0     6931
# 534427010       1728      84900          90       RL         98.0    13260
# 923228270       1092      88250         160       RM         21.0     1900
# 534450090        334      39300          20       RL         50.0     5000
# 535478110       1025     124000         190       RL         70.0     7000
# 923202137       1092     146000          20       RL         77.0     9278
# 902136110       1080      95000          50       RM         44.0     5914
# 903454020        819      72000          30       RM         50.0     9000
# 910200040       1517     115000          50       RM         85.0     8500
# 902401090       1248      93500          90       RM         33.0     5976
# 923228210       1092      79500         160       RM         21.0     1526
# 531363080       1142     139500          20       RL         74.0     7733
# 535450180       1192     135000          50       RL         60.0    10800
# 908229020        864      99900          30       RL         56.0     4060
# 902207010        866     110500          30       RM         40.0     3880
#
#           Street     Alley LotShape LandContour Utilities LotConfig LandSlope  \
# PID
# 903426160   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 909101060   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 903225050   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 903456090   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 535376010   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 903476090   Pave  No_Alley      IR3         Bnk    AllPub    Corner       Gtl
# 909250030   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923228420   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 909101180   Pave      Grvl      Reg         Bnk    AllPub    Inside       Gtl
# 923400125   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 902104060   Pave      Grvl      Reg         Lvl    AllPub    Corner       Gtl
# 910202050   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 531363040   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 531375050   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 903476100   Pave  No_Alley      IR1         Bnk    AllPub    Inside       Gtl
# 902331010   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 534276360   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl
# 535383100   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 908250040   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 903430130   Pave      Grvl      IR1         Bnk    AllPub    Corner       Mod
# 902109080   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 534450150   Pave  No_Alley      Reg         HLS    AllPub    Inside       Gtl
# 907135180   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 909100170   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 527403120   Pave  No_Alley      IR1         Lvl    AllPub    Corner       Gtl
# 534451150   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl
# 908127120   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 534451170   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl
# 911225110   Grvl  No_Alley      Reg         Bnk    AllPub    Inside       Gtl
# 923228290   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 531375090   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 535353160   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 902306120   Pave      Grvl      Reg         Lvl    AllPub    Corner       Gtl
# 527401160   Pave  No_Alley      Reg         Lvl    AllPub       FR2       Gtl
# 532378130   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl
# 904351280   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905101310   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 904101070   Pave  No_Alley      IR1         Bnk    AllPub    Inside       Gtl
# 923204150   Pave  No_Alley      Reg         Low    AllPub    Corner       Gtl
# 534450110   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923226250   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905477010   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 910203090   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908275040   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905426030   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 903454060   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905477050   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 903232170   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 902134120   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 531363050   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923275140   Pave  No_Alley      IR1         Lvl    AllPub    Corner       Gtl
# 902328040   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 903426200   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 535457040   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 903231060   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 911103060   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905200160   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 902109130   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 909177100   Pave      Pave      Reg         Lvl    AllPub    Inside       Gtl
# 908102030   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905452070   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905101100   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 531363060   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908130020   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 907200230   Pave  No_Alley      Reg         HLS    AllPub    Inside       Mod
# 903481100   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 923228080   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908201040   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908103310   Pave  No_Alley      IR1         Lvl    AllPub   CulDSac       Gtl
# 903458110   Pave      Grvl      IR1         Lvl    AllPub    Inside       Gtl
# 527425090   Pave  No_Alley      Reg         Lvl    AllPub       FR2       Gtl
# 910201050   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905101300   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923228150   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 902330010   Pave      Pave      Reg         Lvl    AllPub    Inside       Gtl
# 910201180   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908203100   Pave  No_Alley      Reg         HLS    AllPub    Inside       Gtl
# 908226180   Pave  No_Alley      Reg         Bnk    AllPub    Inside       Mod
# 902128075   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908204180   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 535456050   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 923400150   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 902477120   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 534451020   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 909250210   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905228050   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 911175440   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 903454010   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923226320   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923226180   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908201120   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 910203100   Pave  No_Alley      Reg         Low    AllPub    Inside       Gtl
# 904301060   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 909176170   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 902106130   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 535379110   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 908204160   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923230120   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908102040   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908127100   Grvl  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923228220   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 902456015   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 904302260   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 535456010   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 902105060   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 923228260   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908102130   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 904301375   Pave  No_Alley      IR1         Low    AllPub    Inside       Sev
# 905480150   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 909131125   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 534451120   Pave  No_Alley      IR1         Bnk    AllPub    Inside       Gtl
# 534450180   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl
# 535383060   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 905476170   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl
# 908225170   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 534427010   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl
# 923228270   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 534450090   Pave  No_Alley      Reg         Low    AllPub    Inside       Mod
# 535478110   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923202137   Pave  No_Alley      Reg         Lvl    AllPub       FR2       Gtl
# 902136110   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 903454020   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 910200040   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 902401090   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 923228210   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 531363080   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl
# 535450180   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
# 908229020   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl
# 902207010   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl
#
#           Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# PID
# 903426160      OldTown       Norm       Norm   2fmCon     2.5Unf            6
# 909101060      Edwards       Norm       Norm     1Fam     1Story            3
# 903225050      BrkSide       Norm       Norm     1Fam     1.5Unf            5
# 903456090       IDOTRR       Norm       Norm   2fmCon     1.5Fin            6
# 535376010      OldTown       Norm       Norm     1Fam     1.5Unf            4
# 903476090      OldTown      Feedr       Norm   2fmCon     2.5Unf            7
# 909250030        SWISU      Feedr       Norm     1Fam     1.5Fin            5
# 923228420      MeadowV       Norm       Norm    Twnhs     SFoyer            4
# 909101180        SWISU       Norm       Norm   2fmCon     2Story            5
# 923400125      Mitchel       Norm       Norm     1Fam     SFoyer            5
# 902104060      OldTown       Norm       Norm     1Fam     1.5Fin            4
# 910202050       IDOTRR       Norm       Norm     1Fam     1Story            4
# 531363040      SawyerW       Norm       Norm     1Fam     1Story            7
# 531375050      SawyerW       RRAe       Norm     1Fam     1Story            6
# 903476100      OldTown      Feedr       Norm     1Fam     1.5Unf            5
# 902331010      OldTown       Norm       Norm     1Fam     1Story            4
# 534276360        NAmes       Norm       Norm     1Fam     1Story            4
# 535383100      OldTown       Norm       Norm   2fmCon     2Story            4
# 908250040      Edwards       Norm       Norm     1Fam     1.5Fin            5
# 903430130      OldTown      Feedr       Norm     1Fam     1Story            4
# 902109080      OldTown       Norm       Norm   2fmCon     1.5Fin            4
# 534450150      BrkSide       Norm       Norm     1Fam     1Story            4
# 907135180      CollgCr       Norm       Norm     1Fam     1Story            4
# 909100170      Edwards       Norm       Norm     1Fam     1Story            5
# 527403120        NAmes       Norm       Norm     1Fam     1Story            4
# 534451150      BrkSide       Norm       Norm     1Fam     1Story            3
# 908127120      Edwards       Norm       Norm     1Fam     1Story            5
# 534451170      BrkSide       Norm       Norm     1Fam     1Story            3
# 911225110       IDOTRR       Norm       Norm     1Fam     1.5Fin            3
# 923228290      MeadowV       Norm       Norm    Twnhs     SFoyer            4
# 531375090      SawyerW       RRAe       Norm     1Fam     1Story            5
# 535353160      OldTown     Artery       Norm     1Fam     1.5Fin            4
# 902306120      OldTown       Norm       Norm     1Fam     2Story            5
# 527401160        NAmes       Norm       Norm   Duplex     2Story            5
# 532378130       Sawyer       Norm       Norm     1Fam     1Story            5
# 904351280      Edwards       Norm       Norm   2fmCon     1.5Fin            5
# 905101310       Sawyer       Norm       Norm   Duplex     1Story            4
# 904101070      ClearCr       Norm       Norm     1Fam     1.5Fin            5
# 923204150      Mitchel       Norm       Norm   Duplex     2Story            6
# 534450110      BrkSide       Norm       Norm     1Fam     1Story            3
# 923226250      MeadowV       Norm       Norm    Twnhs     2Story            4
# 905477010      Edwards       Norm       Norm     1Fam     1Story            5
# 910203090       IDOTRR       Norm       Norm     1Fam     1.5Fin            5
# 908275040      Edwards       Norm       Norm   Duplex     1Story            5
# 905426030      Edwards       Norm       Norm     1Fam     1Story            5
# 903454060       IDOTRR       Norm       Norm   2fmCon     2Story            4
# 905477050      Edwards       Norm       Norm   2fmCon     2Story            5
# 903232170      BrkSide       Norm       Norm     1Fam     1.5Fin            4
# 902134120      OldTown       Norm       Norm     1Fam     1.5Fin            5
# 531363050      SawyerW       Norm       Norm     1Fam     1Story            6
# 923275140      Mitchel       Norm       Norm     1Fam     1Story            5
# 902328040      OldTown       Norm       Norm     1Fam     2.5Unf            6
# 903426200      OldTown       Norm       Norm     1Fam     2Story            6
# 535457040        NAmes     Artery       Norm   Duplex     1Story            5
# 903231060      BrkSide       Norm       Norm     1Fam     1Story            2
# 911103060       IDOTRR      Feedr       Norm   2fmCon     2Story            5
# 905200160       Sawyer       Norm       Norm     1Fam     1Story            5
# 902109130      OldTown     Artery       Norm   2fmCon     2Story            4
# 909177100        SWISU       Norm       Norm   Duplex     2Story            4
# 908102030      Edwards      Feedr       Norm     1Fam     1Story            5
# 905452070      Edwards       Norm       Norm   Duplex     SFoyer            5
# 905101100       Sawyer      Feedr       Norm     1Fam     1.5Fin            5
# 531363060      SawyerW       Norm       Norm     1Fam     1Story            7
# 908130020      Edwards       Norm       Norm     1Fam     1Story            6
# 907200230      CollgCr       Norm       Norm     1Fam     1Story            5
# 903481100       IDOTRR       Norm       Norm   2fmCon     2Story            3
# 923228080      MeadowV       Norm       Norm    Twnhs     2Story            6
# 908201040      Edwards       Norm       Norm     1Fam     1Story            5
# 908103310      Edwards       Norm       Norm   Duplex     SFoyer            6
# 903458110       IDOTRR     Artery       Norm     1Fam     1.5Fin            6
# 527425090        NAmes       Norm       Norm     1Fam     1Story            4
# 910201050       IDOTRR     Artery       Norm     1Fam     1.5Fin            5
# 905101300       Sawyer       Norm       Norm   Duplex     1Story            4
# 923228150      MeadowV       Norm       Norm    Twnhs     2Story            4
# 902330010      OldTown       Norm       Norm     1Fam     2Story            8
# 910201180       IDOTRR       Norm       Norm     1Fam     2Story            5
# 908203100      Edwards       Norm       Norm     1Fam     1Story            4
# 908226180      Edwards       Norm       Norm     1Fam     1Story            3
# 902128075      OldTown       Norm       Norm     1Fam     1Story            7
# 908204180      Edwards       Norm       Norm   Duplex     1Story            4
# 535456050        NAmes     Artery       Norm   Duplex     1Story            5
# 923400150      Mitchel       Norm       Norm     1Fam     1Story            5
# 902477120       IDOTRR       Norm       Norm     1Fam     1Story            4
# 534451020      BrkSide      Feedr       Norm     1Fam     1.5Fin            3
# 909250210        SWISU       Norm       Norm     1Fam     1.5Fin            5
# 905228050       Sawyer       Norm       Norm     1Fam     1Story            2
# 911175440       IDOTRR       Norm       Norm   2fmCon     1.5Fin            5
# 903454010       IDOTRR       Norm       Norm     1Fam     2Story            6
# 923226320      MeadowV       Norm       Norm   TwnhsE     SFoyer            4
# 923226180      MeadowV       Norm       Norm    Twnhs     SFoyer            4
# 908201120      Edwards       Norm       Norm   Duplex     1Story            4
# 910203100       IDOTRR       Norm       Norm     1Fam     1Story            4
# 904301060      Edwards       Norm       Norm   Duplex     1Story            5
# 909176170        SWISU       Norm       Norm   Duplex     2Story            5
# 902106130      OldTown     Artery       Norm     1Fam     1Story            5
# 535379110      OldTown       Norm       Norm     1Fam     2Story            5
# 908204160      Edwards       Norm       Norm   Duplex     1Story            4
# 923230120      Mitchel       Norm       Norm     1Fam     SFoyer            5
# 908102040      Edwards      Feedr       Norm   Duplex     1.5Fin            5
# 908127100      Edwards       Norm       Norm   Duplex     SFoyer            6
# 923228220      MeadowV       Norm       Norm   TwnhsE     2Story            4
# 902456015       IDOTRR       Norm       Norm     1Fam     1.5Unf            3
# 904302260        SWISU       Norm       Norm   2fmCon     1.5Fin            5
# 535456010        NAmes       Norm       Norm   Duplex     1Story            5
# 902105060      OldTown       Norm       Norm     1Fam     2Story            5
# 923228260      MeadowV       Norm       Norm    Twnhs     2Story            4
# 908102130      Edwards       Norm       Norm   Duplex     1Story            5
# 904301375      Edwards       Norm       Norm     1Fam     1Story            1
# 905480150      Edwards     Artery       Norm     1Fam     1.5Fin            6
# 909131125        SWISU       Norm       Norm   2fmCon     2Story            5
# 534451120      BrkSide       Norm       Norm     1Fam     1Story            4
# 534450180      BrkSide       Norm       Norm     1Fam     1Story            5
# 535383060      OldTown     Artery       Norm     1Fam     1Story            2
# 905476170      Edwards       Norm       Norm     1Fam     1Story            4
# 908225170      Edwards       Norm       Norm   2fmCon     1Story            4
# 534427010        NAmes       Norm       Norm   Duplex     1Story            5
# 923228270      MeadowV       Norm       Norm   TwnhsE     2Story            4
# 534450090      BrkSide       Norm       Norm     1Fam     1Story            1
# 535478110        NAmes     Artery       Norm   2fmCon     SFoyer            5
# 923202137      Mitchel      Feedr     Artery     1Fam     1Story            5
# 902136110      OldTown       Norm       Norm     1Fam     1.5Fin            5
# 903454020       IDOTRR       Norm       Norm     1Fam     1Story            5
# 910200040       IDOTRR     Artery       Norm     1Fam     1.5Fin            5
# 902401090      OldTown       Norm       Norm   Duplex     2Story            5
# 923228210      MeadowV       Norm       Norm    Twnhs     2Story            4
# 531363080      SawyerW       Norm       Norm     1Fam     1Story            6
# 535450180        NAmes       Norm       Norm     1Fam     1.5Fin            4
# 908229020      Edwards      Feedr       Norm     1Fam     1Story            5
# 902207010      OldTown       Norm       Norm     1Fam     1Story            5
#
#            OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# PID
# 903426160            8       1910          1983     Gable  CompShg
# 909101060            3       1914          1950     Gable  CompShg
# 903225050            6       1924          1950     Gable  CompShg
# 903456090            8       1935          1982     Gable  CompShg
# 535376010            6       1956          1956     Gable  CompShg
# 903476090            5       1902          2000     Gable  CompShg
# 909250030            2       1931          1950     Gable  CompShg
# 923228420            7       1972          1972     Gable  CompShg
# 909101180            6       1912          2000     Gable  CompShg
# 923400125            5       1992          1992     Gable  CompShg
# 902104060            7       1910          2004     Gable  CompShg
# 910202050            4       1922          1950     Gable  CompShg
# 531363040            5       2006          2006     Gable  CompShg
# 531375050            5       2005          2006     Gable  CompShg
# 903476100            7       1930          1950     Gable  CompShg
# 902331010            3       1910          1950     Gable  CompShg
# 534276360            5       1959          1959     Gable  CompShg
# 535383100            7       1900          2000     Gable  CompShg
# 908250040            8       1947          1993     Gable  CompShg
# 903430130            4       1941          1950     Gable  CompShg
# 902109080            6       1910          1996     Gable  CompShg
# 534450150            7       1940          1950       Hip  CompShg
# 907135180            5       1994          1995     Gable  CompShg
# 909100170            6       1925          1950     Gable  CompShg
# 527403120            4       1971          1971     Gable  CompShg
# 534451150            2       1940          1966     Gable  CompShg
# 908127120            6       1940          1969     Gable  CompShg
# 534451170            6       1935          2003     Gable  CompShg
# 911225110            5       1916          1950     Gable  CompShg
# 923228290            6       1970          1970     Gable  CompShg
# 531375090            5       2004          2004     Gable  CompShg
# 535353160            7       1890          2006     Gable  CompShg
# 902306120            9       1905          2005     Gable  CompShg
# 527401160            5       1974          1974     Gable  CompShg
# 532378130            6       1964          1964     Gable  CompShg
# 904351280            7       1940          1999     Gable  CompShg
# 905101310            5       1968          1968       Hip  CompShg
# 904101070            6       1946          1994     Gable  CompShg
# 923204150            5       1971          1971   Mansard  CompShg
# 534450110            3       1946          1950     Gable  CompShg
# 923226250            7       1970          1970     Gable  CompShg
# 905477010            5       1954          1954     Gable  CompShg
# 910203090            7       1930          1950     Gable  CompShg
# 908275040            5       1959          1959       Hip  CompShg
# 905426030            7       1940          2007      Flat  Tar&Grv
# 903454060            5       1930          1950       Hip  CompShg
# 905477050            7       1910          1991     Gable  CompShg
# 903232170            5       1947          1950     Gable  CompShg
# 902134120            5       1910          1950     Gable  CompShg
# 531363050            5       2004          2004     Gable  CompShg
# 923275140            5       1985          1985     Gable  CompShg
# 902328040            6       1914          2001     Gable  CompShg
# 903426200            8       1912          2009     Gable  CompShg
# 535457040            4       1961          1961     Gable  CompShg
# 903231060            3       1936          1950     Gable  CompShg
# 911103060            6       1895          2006     Gable  CompShg
# 905200160            3       1959          1959     Gable  CompShg
# 902109130            6       1920          1950     Gable  CompShg
# 909177100            6       1967          1967      Flat  Tar&Grv
# 908102030            7       1910          1950     Gable  CompShg
# 905452070            5       1975          1975     Gable  CompShg
# 905101100            8       1875          1996     Gable  CompShg
# 531363060            5       2004          2005     Gable  CompShg
# 908130020            5       2002          2002     Gable  CompShg
# 907200230            5       1978          1978     Gable  CompShg
# 903481100            3       1915          1950     Gable  CompShg
# 923228080            9       1970          2007     Gable  CompShg
# 908201040            9       1947          2008       Hip  CompShg
# 908103310            5       1975          1975      Flat  Tar&Grv
# 903458110            7       1920          1950     Gable  CompShg
# 527425090            5       1971          1971     Gable  CompShg
# 910201050            7       1925          2003     Gable  CompShg
# 905101300            3       1967          1967     Gable  Tar&Grv
# 923228150            6       1970          2008     Gable  CompShg
# 902330010            5       1872          1987     Gable  CompShg
# 910201180            6       1923          1999     Gable  CompShg
# 908203100            5       1958          1958       Hip  CompShg
# 908226180            6       1931          2006     Gable  CompShg
# 902128075            6       1920          2006     Gable  CompShg
# 908204180            3       1955          1955     Gable  CompShg
# 535456050            5       1961          1961     Gable  CompShg
# 923400150            5       1991          1992     Gable  CompShg
# 902477120            5       1920          1950     Gable  CompShg
# 534451020            5       1945          1950     Gable  CompShg
# 909250210            5       1926          1950     Gable  CompShg
# 905228050            2       1947          1950     Gable  CompShg
# 911175440            6       1951          1951     Gable  CompShg
# 903454010            7       1914          2006     Gable  CompShg
# 923226320            6       1972          1972     Gable  CompShg
# 923226180            6       1970          1970     Gable  CompShg
# 908201120            4       1955          1955     Gable  CompShg
# 910203100            4       1925          1950     Gable  CompShg
# 904301060            5       1987          1988     Gable  CompShg
# 909176170            6       1923          1950       Hip  CompShg
# 902106130            7       1920          1950     Gable  CompShg
# 535379110            9       1895          1999     Gable  CompShg
# 908204160            5       1955          1955     Gable  CompShg
# 923230120            7       1971          1971     Gable  CompShg
# 908102040            7       1900          2003     Gable  CompShg
# 908127100            5       1990          1990     Gable  CompShg
# 923228220            6       1970          1970     Gable  CompShg
# 902456015            3       1918          1950     Gable  CompShg
# 904302260            4       1915          1950     Gable  CompShg
# 535456010            5       1960          1960       Hip  CompShg
# 902105060            8       1910          2002     Gable  CompShg
# 923228260            7       1970          1970     Gable  CompShg
# 908102130            5       1965          1965       Hip  CompShg
# 904301375            1       1922          1950     Gable  CompShg
# 905480150            5       1924          1950     Gable  CompShg
# 909131125            8       1916          1995     Gable  CompShg
# 534451120            7       1923          1958     Gable  CompShg
# 534450180            7       1958          2008     Gable  CompShg
# 535383060            5       1940          1950     Gable  CompShg
# 905476170            7       1920          2002     Gable  CompShg
# 908225170            5       1955          1955       Hip  CompShg
# 534427010            6       1962          2001       Hip  CompShg
# 923228270            4       1970          1970     Gable  CompShg
# 534450090            3       1946          1950     Gable  CompShg
# 535478110            5       1962          1962     Gable  CompShg
# 923202137            5       2007          2008     Gable  CompShg
# 902136110            9       1890          1996     Gable  CompShg
# 903454020            4       1919          1950     Gable  CompShg
# 910200040            7       1919          2005     Gable  CompShg
# 902401090            7       1920          1950       Hip  CompShg
# 923228210            5       1970          1970     Gable  CompShg
# 531363080            5       2005          2005     Gable  CompShg
# 535450180            4       1949          1950     Gable  CompShg
# 908229020            8       1922          1950     Gable  CompShg
# 902207010            9       1945          1997     Gable  CompShg
#
#           Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# PID
# 903426160     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 909101060      Stucco      Stucco       None         0.0        TA        TA
# 903225050     MetalSd     MetalSd       None         0.0        TA        TA
# 903456090     Wd Sdng     Wd Sdng       None         0.0        TA        Fa
# 535376010     MetalSd     MetalSd       None         0.0        TA        TA
# 903476090     MetalSd     MetalSd      Stone       188.0        TA        Fa
# 909250030     VinylSd     VinylSd       None         0.0        TA        TA
# 923228420     CemntBd     CmentBd       None         0.0        TA        Gd
# 909101180     VinylSd     VinylSd       None         0.0        TA        Fa
# 923400125     HdBoard     Wd Shng       None         0.0        TA        TA
# 902104060     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 910202050     AsbShng     AsbShng       None         0.0        TA        TA
# 531363040     VinylSd     VinylSd       None         0.0        Gd        TA
# 531375050     VinylSd     VinylSd    BrkFace       126.0        TA        TA
# 903476100     WdShing     Wd Sdng       None         0.0        TA        Gd
# 902331010      Stucco      Stucco       None         0.0        TA        TA
# 534276360     Plywood     Plywood       None         0.0        TA        TA
# 535383100     MetalSd     MetalSd       None         0.0        TA        TA
# 908250040     MetalSd     MetalSd       None         0.0        TA        Gd
# 903430130     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 902109080     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 534450150     VinylSd     VinylSd       None         0.0        Fa        TA
# 907135180     VinylSd     VinylSd       None         0.0        TA        TA
# 909100170      Stucco      Stucco       None         0.0        TA        TA
# 527403120     HdBoard     HdBoard       None         0.0        TA        TA
# 534451150     Wd Sdng     Plywood       None         0.0        TA        Po
# 908127120     WdShing     Wd Shng       None         0.0        TA        TA
# 534451170     VinylSd     VinylSd       None         0.0        Gd        TA
# 911225110     MetalSd     MetalSd       None         0.0        TA        TA
# 923228290     CemntBd     CmentBd       None         0.0        TA        TA
# 531375090     VinylSd     VinylSd       None         0.0        TA        TA
# 535353160     VinylSd     VinylSd       None         0.0        Gd        Gd
# 902306120     MetalSd     MetalSd       None         0.0        Gd        TA
# 527401160     VinylSd     VinylSd       None         0.0        TA        TA
# 532378130     HdBoard     HdBoard       None         0.0        TA        TA
# 904351280     Wd Sdng     Wd Sdng       None         0.0        TA        Gd
# 905101310     HdBoard     HdBoard       None         0.0        TA        TA
# 904101070     MetalSd     MetalSd       None         0.0        TA        TA
# 923204150     MetalSd     Wd Shng       None         0.0        TA        TA
# 534450110     WdShing     Wd Shng       None         0.0        Fa        Fa
# 923226250     CemntBd     CmentBd       None         0.0        TA        TA
# 905477010     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 910203090     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 908275040     VinylSd     VinylSd    BrkFace        74.0        TA        TA
# 905426030     PreCast     PreCast       None         0.0        TA        TA
# 903454060     VinylSd     Wd Shng       None         0.0        Fa        Fa
# 905477050     MetalSd     MetalSd       None         0.0        TA        TA
# 903232170     AsbShng     AsbShng       None         0.0        TA        TA
# 902134120     MetalSd     MetalSd       None         0.0        TA        TA
# 531363050     VinylSd     VinylSd       None         0.0        TA        TA
# 923275140     HdBoard     Plywood       None         0.0        TA        TA
# 902328040     Wd Sdng     Wd Shng       None         0.0        TA        TA
# 903426200     Wd Sdng     Wd Sdng       None         0.0        Gd        Gd
# 535457040     BrkFace     BrkFace       None         0.0        TA        TA
# 903231060     AsbShng     AsbShng       None         0.0        Fa        Fa
# 911103060     VinylSd     VinylSd       None         0.0        TA        Gd
# 905200160     Wd Sdng     Plywood       None         0.0        TA        TA
# 902109130     AsbShng     AsbShng       None         0.0        Fa        TA
# 909177100     Plywood      CBlock       None         0.0        TA        TA
# 908102030     MetalSd     Wd Sdng       None         0.0        TA        TA
# 905452070     HdBoard     HdBoard       None         0.0        TA        TA
# 905101100     VinylSd     VinylSd       None         0.0        TA        Gd
# 531363060     VinylSd     VinylSd    BrkFace       120.0        TA        TA
# 908130020     VinylSd     VinylSd       None         0.0        TA        TA
# 907200230     HdBoard     HdBoard    BrkFace       136.0        TA        TA
# 903481100     AsphShn     AsphShn       None         0.0        Fa        Fa
# 923228080     CemntBd     CmentBd       None         0.0        TA        Gd
# 908201040     VinylSd     VinylSd       None         0.0        TA        Ex
# 908103310     Plywood     Wd Shng    BrkFace       355.0        TA        TA
# 903458110     MetalSd     MetalSd       None         0.0        TA        Fa
# 527425090     HdBoard     HdBoard       None         0.0        TA        TA
# 910201050     VinylSd     VinylSd       None         0.0        Gd        Gd
# 905101300     Plywood     Plywood    BrkFace        72.0        Fa        Fa
# 923228150     CemntBd     CmentBd       None         0.0        TA        TA
# 902330010     MetalSd     MetalSd       None         0.0        TA        Gd
# 910201180     Wd Sdng     Plywood       None         0.0        TA        TA
# 908203100     WdShing     Wd Shng       None         0.0        TA        TA
# 908226180     MetalSd     MetalSd       None         0.0        TA        TA
# 902128075      Stucco      Stucco       None         0.0        Gd        TA
# 908204180     AsbShng     Plywood     BrkCmn       128.0        TA        TA
# 535456050     BrkFace     Wd Sdng       None         0.0        TA        TA
# 923400150     HdBoard     HdBoard       None         0.0        TA        TA
# 902477120     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 534451020     MetalSd     MetalSd       None         0.0        TA        TA
# 909250210     Wd Sdng     Wd Sdng       None         0.0        TA        Fa
# 905228050     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 911175440     WdShing     Wd Shng       None         0.0        Fa        Fa
# 903454010     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 923226320     CemntBd     CmentBd       None         0.0        TA        TA
# 923226180     CemntBd     CmentBd       None         0.0        TA        TA
# ...
# 908102040           70              0          0            0         0
# 908127100           32              0          0            0         0
# 923228220           64              0          0            0         0
# 902456015            0            105          0            0         0
# 904302260            0            168          0            0         0
# 535456010            0              0          0            0         0
# 902105060            0            176          0            0         0
# 923228260            0              0          0            0         0
# 908102130            0              0          0            0         0
# 904301375            0              0          0            0         0
# 905480150            8            128          0            0         0
# 909131125            0            228          0            0         0
# 534451120            0              0          0            0         0
# 534450180            0              0          0            0         0
# 535383060           81              0          0            0         0
# 905476170            0            144          0            0         0
# 908225170            0              0          0            0         0
# 534427010            0              0          0            0         0
# 923228270            0              0          0            0         0
# 534450090            0              0          0            0         0
# 535478110           80              0          0            0         0
# 923202137           52              0          0            0         0
# 902136110          165             30          0            0         0
# 903454020            0              0          0            0         0
# 910200040            0            144          0            0         0
# 902401090          130            256          0            0         0
# 923228210           34              0          0            0         0
# 531363080           50              0          0            0         0
# 535450180            0              0          0            0         0
# 908229020           96              0          0            0         0
# 902207010           42              0          0            0         0
#
#             PoolQC     Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# PID
# 903426160  No_Pool     MnPrv        Shed     1000       9    2008      WD
# 909101060  No_Pool  No_Fence        None        0       9    2008      WD
# 903225050  No_Pool  No_Fence        None        0       5    2008      WD
# 903456090  No_Pool  No_Fence        None        0       6    2006      WD
# 535376010  No_Pool     MnPrv        None        0       4    2007      WD
# 903476090  No_Pool  No_Fence        None        0       5    2009      WD
# 909250030  No_Pool  No_Fence        None        0       5    2010      WD
# 923228420  No_Pool  No_Fence        None        0       6    2008      WD
# 909101180  No_Pool  No_Fence        None        0       3    2008      WD
# 923400125  No_Pool     MnPrv        Shed      700       7    2006      WD
# 902104060  No_Pool  No_Fence        None        0       6    2010      WD
# 910202050  No_Pool     MnPrv        None        0       1    2008      WD
# 531363040  No_Pool  No_Fence        None        0      10    2007      WD
# 531375050  No_Pool  No_Fence        None        0       6    2008      WD
# 903476100  No_Pool  No_Fence        None        0       6    2007      WD
# 902331010  No_Pool  No_Fence        None        0       6    2009      WD
# 534276360  No_Pool  No_Fence        Shed      400       1    2010      WD
# 535383100  No_Pool  No_Fence        None        0       8    2008      WD
# 908250040  No_Pool  No_Fence        None        0       4    2008      WD
# 903430130  No_Pool  No_Fence        None        0       3    2006      WD
# 902109080  No_Pool  No_Fence        None        0       6    2008      WD
# 534450150  No_Pool  No_Fence        None        0      12    2009      WD
# 907135180  No_Pool  No_Fence        None        0       8    2007      WD
# 909100170  No_Pool  No_Fence        None        0       4    2008      WD
# 527403120  No_Pool  No_Fence        None        0       6    2006      WD
# 534451150  No_Pool      GdWo        Shed      450       5    2010      WD
# 908127120  No_Pool  No_Fence        None        0       7    2008      WD
# 534451170  No_Pool  No_Fence        None        0       7    2008      WD
# 911225110  No_Pool  No_Fence        None        0       4    2006      WD
# 923228290  No_Pool     MnPrv        None        0      12    2007      WD
# 531375090  No_Pool  No_Fence        None        0       8    2009      WD
# 535353160  No_Pool  No_Fence        None        0       4    2007      WD
# 902306120  No_Pool  No_Fence        None        0       2    2008      WD
# 527401160  No_Pool  No_Fence        None        0       9    2009      WD
# 532378130  No_Pool      GdWo        None        0       4    2006      WD
# 904351280  No_Pool  No_Fence        None        0       9    2008      WD
# 905101310  No_Pool  No_Fence        None        0       4    2010      WD
# 904101070  No_Pool     MnPrv        None        0       3    2007      WD
# 923204150  No_Pool  No_Fence        None        0       4    2010      WD
# 534450110  No_Pool     MnPrv        None        0       4    2007      WD
# 923226250  No_Pool  No_Fence        None        0       3    2010      WD
# 905477010  No_Pool  No_Fence        None        0       4    2006      WD
# 910203090  No_Pool  No_Fence        None        0       7    2008      WD
# 908275040  No_Pool  No_Fence        None        0       8    2009      WD
# 905426030  No_Pool  No_Fence        None        0       1    2008      WD
# 903454060  No_Pool  No_Fence        Othr     3500       7    2010      WD
# 905477050  No_Pool  No_Fence        None        0       1    2008      WD
# 903232170  No_Pool  No_Fence        None        0       7    2006      WD
# 902134120  No_Pool  No_Fence        None        0       7    2009      WD
# 531363050  No_Pool  No_Fence        None        0       8    2009      WD
# 923275140  No_Pool     MnPrv        None        0       3    2009      WD
# 902328040  No_Pool  No_Fence        None        0       6    2008      WD
# 903426200  No_Pool  No_Fence        None        0       5    2010      WD
# 535457040  No_Pool  No_Fence        None        0       7    2007      WD
# 903231060  No_Pool  No_Fence        None        0       1    2009    ConLw
# 911103060  No_Pool  No_Fence        None        0       6    2007      WD
# 905200160  No_Pool  No_Fence        None        0       7    2008      WD
# 902109130  No_Pool  No_Fence        None        0      10    2009      WD
# 909177100  No_Pool  No_Fence        Shed      500       2    2010      WD
# 908102030  No_Pool     MnPrv        None        0       5    2008      WD
# 905452070  No_Pool  No_Fence        None        0       4    2008      WD
# 905101100  No_Pool  No_Fence        None        0       5    2010      WD
# 531363060  No_Pool  No_Fence        None        0       4    2008      WD
# 908130020  No_Pool  No_Fence        None        0       4    2006      WD
# 907200230  No_Pool  No_Fence        None        0       8    2009      WD
# 903481100  No_Pool  No_Fence        None        0       5    2008      WD
# 923228080  No_Pool  No_Fence        None        0       3    2008      WD
# 908201040  No_Pool  No_Fence        None        0       6    2009      WD
# 908103310  No_Pool  No_Fence        None        0      10    2006      WD
# 903458110  No_Pool     MnPrv        None        0       3    2008      WD
# 527425090  No_Pool  No_Fence        None        0       4    2010    ConLI
# 910201050  No_Pool  No_Fence        None        0       9    2007      WD
# 905101300  No_Pool  No_Fence        None        0       5    2010      WD
# 923228150  No_Pool  No_Fence        None        0       5    2009      WD
# 902330010  No_Pool  No_Fence        None        0      12    2008      WD
# 910201180  No_Pool     MnPrv        None        0       3    2007      WD
# 908203100  No_Pool     MnPrv        None        0       5    2010      WD
# 908226180  No_Pool  No_Fence        None        0       5    2007      WD
# 902128075  No_Pool  No_Fence        None        0       2    2008      WD
# 908204180  No_Pool  No_Fence        None        0       9    2007      WD
# 535456050  No_Pool  No_Fence        None        0      11    2008      WD
# 923400150  No_Pool     MnPrv        None        0       9    2007      Oth
# 902477120  No_Pool      GdWo        None        0      11    2009      WD
# 534451020  No_Pool     MnPrv        Shed     2000       7    2007      WD
# 909250210  No_Pool  No_Fence        None        0       6    2006      WD
# 905228050  No_Pool  No_Fence        None        0       6    2009      WD
# 911175440  No_Pool  No_Fence        None        0      10    2006      WD
# 903454010  No_Pool  No_Fence        None        0       3    2007      WD
# 923226320  No_Pool  No_Fence        None        0       5    2010      WD
# 923226180  No_Pool  No_Fence        None        0       4    2006      WD
# 908201120  No_Pool  No_Fence        None        0       9    2008      WD
# 910203100  No_Pool      GdWo        None        0       6    2006      WD
# 904301060  No_Pool  No_Fence        None        0       3    2009      WD
# 909176170  No_Pool  No_Fence        Shed     1512       1    2007      WD
# 902106130  No_Pool     MnPrv        None        0       5    2010      WD
# 535379110  No_Pool  No_Fence        None        0       7    2007      WD
# 908204160  No_Pool  No_Fence        None        0       7    2008      WD
# 923230120  No_Pool      GdWo        None        0       9    2007      WD
# 908102040  No_Pool     GdPrv        None        0       9    2008      WD
# 908127100  No_Pool  No_Fence        None        0       5    2007      WD
# 923228220  No_Pool  No_Fence        None        0       5    2007      WD
# 902456015  No_Pool  No_Fence        None        0      10    2006    ConLD
# 904302260  No_Pool  No_Fence        None        0       2    2010    ConLD
# 535456010  No_Pool  No_Fence        None        0       9    2006      WD
# 902105060  No_Pool  No_Fence        None        0       3    2009      WD
# 923228260  No_Pool  No_Fence        None        0       6    2006      WD
# 908102130  No_Pool  No_Fence        None        0       5    2010      WD
# 904301375  No_Pool  No_Fence        None        0       3    2009      WD
# 905480150  No_Pool  No_Fence        None        0       4    2008      WD
# 909131125  No_Pool  No_Fence        None        0       7    2006      WD
# 534451120  No_Pool  No_Fence        None        0       8    2006      WD
# 534450180  No_Pool  No_Fence        None        0       2    2010      WD
# 535383060  No_Pool  No_Fence        None        0       6    2009      WD
# 905476170  No_Pool  No_Fence        None        0       7    2007      WD
# 908225170  No_Pool  No_Fence        None        0       5    2008      WD
# 534427010  No_Pool  No_Fence        None        0       1    2010      Oth
# 923228270  No_Pool  No_Fence        None        0       6    2010      WD
# 534450090  No_Pool  No_Fence        None        0       1    2007      WD
# 535478110  No_Pool  No_Fence        None        0       3    2006      WD
# 923202137  No_Pool  No_Fence        None        0       2    2008      WD
# 902136110  No_Pool  No_Fence        None        0       9    2008      WD
# 903454020  No_Pool  No_Fence        None        0       9    2006      WD
# 910200040  No_Pool  No_Fence        None        0       8    2007      WD
# 902401090  No_Pool  No_Fence        None        0      12    2006      WD
# 923228210  No_Pool     GdPrv        None        0       6    2006      WD
# 531363080  No_Pool  No_Fence        None        0       1    2006      WD
# 535450180  No_Pool  No_Fence        None        0      12    2006      WD
# 908229020  No_Pool  No_Fence        None        0       7    2009      WD
# 902207010  No_Pool  No_Fence        None        0       8    2007      WD
#
#           SaleCondition
# PID
# 903426160        Normal
# 909101060        Normal
# 903225050        Normal
# 903456090        Normal
# 535376010        Normal
# 903476090        Normal
# 909250030        Normal
# 923228420        Normal
# 909101180        Normal
# 923400125        Normal
# 902104060        Normal
# 910202050        Normal
# 531363040        Normal
# 531375050        Normal
# 903476100        Normal
# 902331010        Normal
# 534276360        Normal
# 535383100        Normal
# 908250040        Normal
# 903430130        Normal
# 902109080        Normal
# 534450150        Normal
# 907135180        Normal
# 909100170        Normal
# 527403120        Normal
# 534451150        Normal
# 908127120        Normal
# 534451170        Normal
# 911225110        Normal
# 923228290        Normal
# 531375090        Normal
# 535353160        Normal
# 902306120        Normal
# 527401160        Normal
# 532378130        Normal
# 904351280        Normal
# 905101310        Normal
# 904101070        Normal
# 923204150        Normal
# 534450110        Normal
# 923226250        Normal
# 905477010        Normal
# 910203090        Normal
# 908275040        Normal
# 905426030        Normal
# 903454060        Normal
# 905477050        Normal
# 903232170        Normal
# 902134120        Normal
# 531363050        Normal
# 923275140        Normal
# 902328040        Normal
# 903426200        Normal
# 535457040        Normal
# 903231060        Normal
# 911103060        Normal
# 905200160        Normal
# 902109130        Normal
# 909177100        Normal
# 908102030        Normal
# 905452070        Normal
# 905101100        Normal
# 531363060        Normal
# 908130020        Normal
# 907200230        Normal
# 903481100        Normal
# 923228080        Normal
# 908201040        Normal
# 908103310       AdjLand
# 903458110        Normal
# 527425090        Normal
# 910201050        Normal
# 905101300        Normal
# 923228150        Normal
# 902330010        Normal
# 910201180        Alloca
# 908203100        Normal
# 908226180        Normal
# 902128075        Normal
# 908204180        Normal
# 535456050       Abnorml
# 923400150       Abnorml
# 902477120       Abnorml
# 534451020        Normal
# 909250210        Normal
# 905228050        Normal
# 911175440       Abnorml
# 903454010        Normal
# 923226320        Normal
# 923226180        Normal
# 908201120        Normal
# 910203100        Normal
# 904301060        Alloca
# 909176170       AdjLand
# 902106130        Normal
# 535379110        Normal
# 908204160        Normal
# 923230120        Normal
# 908102040        Normal
# 908127100        Normal
# 923228220        Normal
# 902456015        Normal
# 904302260        Normal
# 535456010        Normal
# 902105060        Normal
# 923228260        Normal
# 908102130        Normal
# 904301375        Normal
# 905480150        Normal
# 909131125        Normal
# 534451120        Normal
# 534450180        Normal
# 535383060        Normal
# 905476170        Normal
# 908225170        Normal
# 534427010       Abnorml
# 923228270        Normal
# 534450090        Normal
# 535478110        Normal
# 923202137       Abnorml
# 902136110        Normal
# 903454020       Abnorml
# 910200040        Normal
# 902401090        Normal
# 923228210        Normal
# 531363080        Normal
# 535450180       Abnorml
# 908229020        Normal
# 902207010        Normal

# %%
print(housing["SaleType"].value_counts())
print(housing["SaleCondition"].value_counts())
# Out:
# WD       2392
# New        79
# COD        50
# ConLD      23
# CWD        11
# ConLw       8
# ConLI       7
# Con         5
# Oth         4
# VWD         1
# Name: SaleType, dtype: int64
# Normal     2414
# Partial      82
# Abnorml      61
# Family       17
# Alloca        4
# AdjLand       2
# Name: SaleCondition, dtype: int64

# %%
# Filter the DataFrame to only include rows where SaleType is "Family"
family_sales = housing[housing["SaleType"] == "Family"]

# Print the mean, median, and standard deviation of SalePrice in the filtered DataFrame
print("SalePrice statistics for Family sales:")
print("Mean: ", family_sales["SalePrice"].mean())
print("Median: ", family_sales["SalePrice"].median())
print("Standard deviation: ", family_sales["SalePrice"].std())

# Print the mean, median, and standard deviation of SalePrice in the entire dataset
print("\nSalePrice statistics for all sales:")
print("Mean: ", housing["SalePrice"].mean())
print("Median: ", housing["SalePrice"].median())
print("Standard deviation: ", housing["SalePrice"].std())
# Out:
# SalePrice statistics for Family sales:
# Mean:  nan
# Median:  nan
# Standard deviation:  nan
#
# SalePrice statistics for all sales:
# Mean:  178059.62325581396
# Median:  159900.0
# Standard deviation:  75031.08937358031

# %%
print(housing[housing["SalePrice"].isna()])
# Out:
# Empty DataFrame
# Columns: [GrLivArea, SalePrice, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
housing[housing["GarageCars"] == 360.0]
# Out:
# Empty DataFrame
# Columns: [GrLivArea, SalePrice, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
# Filter the data to include only the relevant columns
housing_3_col = housing[["MSZoning", "Neighborhood", "SalePrice"]]

# Visualize the relationship between MSZoning and SalePrice
sns.boxplot(x="MSZoning", y="SalePrice", data=housing_3_col)
sns.stripplot(x="MSZoning", y="SalePrice", data=housing_3_col, color=".3")
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='SalePrice'>

# %%
# Visualize the relationship between Neighborhood and SalePrice
sns.boxplot(x="Neighborhood", y="SalePrice", data=housing_3_col)
sns.stripplot(x="Neighborhood", y="SalePrice", data=housing_3_col, color=".3")
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='SalePrice'>

# %%
# Create a pivot table to summarize the average SalePrice by MSZoning and Neighborhood
table = pd.pivot_table(
    housing_3_col,
    values="SalePrice",
    index="MSZoning",
    columns="Neighborhood",
    aggfunc="mean",
)

# Use a heatmap to visualize the pivot table
sns.heatmap(table, cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='MSZoning'>

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 5.4 MB/s ta 0:00:011
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from folium) (2.27.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (from folium) (1.21.5)
# Requirement already satisfied: jinja2>=2.9 in /opt/anaconda3/lib/python3.9/site-packages (from folium) (2.11.3)
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (3.3)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0
# ERROR:root:Cannot parse: 1:4: pip install folium
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/lab_black.py", line 218, in format_cell
#     formatted_code = _format_code(cell)
#   File "/opt/anaconda3/lib/python3.9/site-packages/lab_black.py", line 29, in _format_code
#     return format_str(src_contents=code, mode=FileMode())
#   File "/opt/anaconda3/lib/python3.9/site-packages/black.py", line 725, in format_str
#     src_node = lib2to3_parse(src_contents.lstrip(), mode.target_versions)
#   File "/opt/anaconda3/lib/python3.9/site-packages/black.py", line 836, in lib2to3_parse
#     raise exc from None
# black.InvalidInput: Cannot parse: 1:4: pip install folium
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# create a map centered on the median latitude and longitude of the housing data
map_center = [housing['latitude'].median(), housing['longitude'].median()]
m = folium.Map(location=map_center, zoom_start=10)

# add a marker for each house, with the sale price displayed as a tooltip
for index, row in housing.iterrows():
    tooltip = f"${row['SalePrice']:,}"
    folium.Marker(location=[row['latitude'], row['longitude']], tooltip=tooltip).add_to(m)

# display the map
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 8>()
#       8 for index, row in housing.iterrows():
#       9     tooltip = f"${row['SalePrice']:,}"
# ---> 10     folium.Marker(location=[row['latitude'], row['longitude']], tooltip=tooltip).add_to(m)
#      12 # display the map
#      13 m
#
# File /opt/anaconda3/lib/python3.9/site-packages/folium/map.py:326, in Marker.__init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     324 super().__init__()
#     325 self._name = "Marker"
# --> 326 self.location = validate_location(location) if location is not None else None
#     327 self.options = parse_options(
#     328     draggable=draggable or None, autoPan=draggable or None, **kwargs
#     329 )
#     330 if icon is not None:
#
# File /opt/anaconda3/lib/python3.9/site-packages/folium/utilities.py:78, in validate_location(location)
#      71         raise ValueError(
#      72             "Location should consist of two numerical values, "
#      73             "but {!r} of type {} is not convertible to float.".format(
#      74                 coord, type(coord)
#      75             )
#      76         )
#      77     if math.isnan(float(coord)):
# ---> 78         raise ValueError("Location values cannot contain NaNs.")
#      79 return [float(x) for x in coords]
#
# ValueError: Location values cannot contain NaNs.

# %%
# Looking at the NA's again
null_stats = (
    housing.isnull()
    .sum()
    .pipe(lambda x: pd.DataFrame({"missing_value_count": x}))
    .assign(
        percent_of_dataset=lambda x: np.round(
            x["missing_value_count"] / housing.shape[0] * 100, 2
        )
    )
    .query("missing_value_count > 0")
    .sort_values(by="missing_value_count", ascending=False)
)
print(null_stats)
# Out:
#               missing_value_count  percent_of_dataset
# PoolQC                       2595               99.65
# MiscFeature                  2506               96.24
# Alley                        2434               93.47
# Fence                        2075               79.69
# FireplaceQu                  1262               48.46
# LotFrontage                   463               17.78
# GarageCond                    130                4.99
# GarageQual                    130                4.99
# GarageFinish                  130                4.99
# GarageYrBlt                   130                4.99
# GarageType                    128                4.92
# BsmtExposure                   67                2.57
# BsmtFinType2                   66                2.53
# BsmtCond                       65                2.50
# BsmtFinType1                   65                2.50
# BsmtQual                       65                2.50
# latitude                       48                1.84
# longitude                      48                1.84
# MasVnrArea                     14                0.54
# MasVnrType                     14                0.54
# BsmtHalfBath                    2                0.08
# BsmtFullBath                    2                0.08
# Electrical                      1                0.04
# GarageCars                      1                0.04
# GarageArea                      1                0.04
# TotalBsmtSF                     1                0.04
# BsmtUnfSF                       1                0.04
# BsmtFinSF2                      1                0.04
# BsmtFinSF1                      1                0.04

# %%
housing = pd.read_csv("../data/housing_lat_lon.csv", index_col=0)
housing
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 0     909176150        856     126000          30       RL          NaN
# 1     905476230       1049     139500         120       RL         42.0
# 2     905476230       1049     139500         120       RL         42.0
# 3     911128020       1001     124900          30  C (all)         60.0
# 4     535377150       1039     114000          70       RL         80.0
# ...         ...        ...        ...         ...      ...          ...
# 2599  903205040        952     121000          30       RL          NaN
# 2600  905402060       1733     139600          20       RL          NaN
# 2601  909275030       2002     145000          90       RH         82.0
# 2602  907192040       1842     217500          60       RL          NaN
# 2603  906223180       1911     215000          60       RL         80.0
#
#       LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0        7890   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 1        4235   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2        4235   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 3        6060   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 4        8146   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 2599     8854   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2600    13680   Pave   NaN      IR1         Lvl    AllPub   CulDSac       Gtl
# 2601     6270   Pave   NaN      Reg         HLS    AllPub    Inside       Gtl
# 2602     8826   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2603     9554   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 0           SWISU       Norm       Norm     1Fam     1Story            6
# 1         Edwards       Norm       Norm   TwnhsE     1Story            5
# 2         Edwards       Norm       Norm   TwnhsE     1Story            5
# 3          IDOTRR       Norm       Norm     1Fam     1Story            5
# 4         OldTown       Norm       Norm     1Fam     2Story            4
# ...           ...        ...        ...      ...        ...          ...
# 2599      BrkSide       Norm       Norm     1Fam     1.5Unf            6
# 2600      Edwards       Norm       Norm     1Fam     1Story            3
# 2601      Crawfor       Norm       Norm   Duplex     2Story            5
# 2602      CollgCr       Norm       Norm     1Fam     2Story            7
# 2603      SawyerW       Norm       Norm     1Fam     2Story            8
#
#       OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 0               6       1939          1950     Gable  CompShg     Wd Sdng
# 1               5       1984          1984     Gable  CompShg     HdBoard
# 2               5       1984          1984     Gable  CompShg     HdBoard
# 3               9       1930          2007       Hip  CompShg     MetalSd
# 4               8       1900          2003     Gable  CompShg     MetalSd
# ...           ...        ...           ...       ...      ...         ...
# 2599            6       1916          1950     Gable  CompShg     Wd Sdng
# 2600            5       1955          1955       Hip  CompShg     BrkFace
# 2601            6       1949          1950     Gable  CompShg     MetalSd
# 2602            5       2000          2000     Gable  CompShg     VinylSd
# 2603            5       1993          1994     Gable  CompShg     VinylSd
#
#      Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation  \
# 0        Wd Sdng       None         0.0        TA        TA     CBlock
# 1        HdBoard    BrkFace       149.0        Gd        TA     CBlock
# 2        HdBoard    BrkFace       149.0        Gd        TA     CBlock
# 3        MetalSd       None         0.0        Gd        TA     BrkTil
# 4        MetalSd       None         0.0        Gd        Gd     BrkTil
# ...          ...        ...         ...       ...       ...        ...
# 2599     Wd Sdng       None         0.0        TA        TA     BrkTil
# 2600     Wd Sdng       None         0.0        TA        TA       Slab
# 2601     MetalSd       None         0.0        TA        TA     CBlock
# 2602     VinylSd    BrkFace       144.0        Gd        TA      PConc
# 2603     VinylSd    BrkFace       125.0        Gd        TA      PConc
#
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 0          TA       TA           No          Rec       238.0          Unf
# 1          Gd       TA           Mn          GLQ       552.0          ALQ
# 2          Gd       TA           Mn          GLQ       552.0          ALQ
# 3          TA       TA           No          ALQ       737.0          Unf
# 4          Fa       TA           No          Unf         0.0          Unf
# ...       ...      ...          ...          ...         ...          ...
# 2599       TA       TA           No          Unf         0.0          Unf
# 2600      NaN      NaN          NaN          NaN         0.0          NaN
# 2601       TA       TA           No          BLQ       284.0          Unf
# 2602       Gd       TA           No          GLQ       841.0          Unf
# 2603       Gd       TA           No          GLQ       380.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# 0            0.0      618.0        856.0    GasA        TA          Y
# 1          393.0      104.0       1049.0    GasA        TA          Y
# 2          393.0      104.0       1049.0    GasA        TA          Y
# 3            0.0      100.0        837.0    GasA        Ex          Y
# 4            0.0      405.0        405.0    GasA        Gd          Y
# ...          ...        ...          ...     ...       ...        ...
# 2599         0.0      952.0        952.0    Grav        Fa          N
# 2600         0.0        0.0          0.0    GasA        Ex          Y
# 2601         0.0      717.0       1001.0    GasA        TA          N
# 2602         0.0      144.0        985.0    GasA        Ex          Y
# 2603         0.0      397.0        777.0    GasA        Ex          Y
#
#      Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  \
# 0         SBrkr       856         0             0           1.0           0.0
# 1         SBrkr      1049         0             0           1.0           0.0
# 2         SBrkr      1049         0             0           1.0           0.0
# 3         SBrkr      1001         0             0           0.0           0.0
# 4         SBrkr       717       322             0           0.0           0.0
# ...         ...       ...       ...           ...           ...           ...
# 2599      FuseF       952         0             0           0.0           0.0
# 2600      FuseA      1733         0             0           0.0           0.0
# 2601      FuseA      1001      1001             0           0.0           0.0
# 2602      SBrkr       985       857             0           1.0           0.0
# 2603      SBrkr      1065       846             0           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            1         0             2             1          TA
# 1            2         0             2             1          Gd
# 2            2         0             2             1          Gd
# 3            1         0             2             1          Gd
# 4            1         0             2             1          TA
# ...        ...       ...           ...           ...         ...
# 2599         1         0             2             1          Fa
# 2600         2         0             4             1          TA
# 2601         2         0             4             2          TA
# 2602         2         1             3             1          Gd
# 2603         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                4        Typ           1          Gd     Detchd       1939.0
# 1                5        Typ           0         NaN     Attchd       1984.0
# 2                5        Typ           0         NaN     Attchd       1984.0
# 3                5        Typ           0         NaN     Detchd       1930.0
# 4                6        Typ           0         NaN     Detchd       1940.0
# ...            ...        ...         ...         ...        ...          ...
# 2599             4        Typ           1          Gd     Detchd       1916.0
# 2600             8       Min2           1          Gd     Attchd       1955.0
# 2601             8        Typ           0         NaN     2Types       1949.0
# 2602             7        Typ           1          TA     Attchd       2000.0
# 2603             8        Typ           1          TA     Attchd       1993.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             Unf         2.0       399.0         TA         TA          Y
# 1             Fin         1.0       266.0         TA         TA          Y
# 2             Fin         1.0       266.0         TA         TA          Y
# 3             Unf         1.0       216.0         TA         Po          N
# 4             Unf         1.0       281.0         TA         TA          N
# ...           ...         ...         ...        ...        ...        ...
# 2599          Unf         1.0       192.0         Fa         Po          P
# 2600          Unf         2.0       452.0         TA         TA          Y
# 2601          Unf         3.0       871.0         TA         TA          Y
# 2602          Fin         2.0       486.0         TA         TA          Y
# 2603          RFn         2.0       471.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0            0              0          0          166
# 1              0          105              0          0            0
# 2              0          105              0          0            0
# 3            154            0             42         86            0
# 4              0            0            168          0          111
# ...          ...          ...            ...        ...          ...
# 2599           0           98              0          0           40
# 2600           0            0              0          0            0
# 2601           0            0              0          0            0
# 2602         193           96              0          0            0
# 2603         182           81              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN   NaN         NaN        0       3    2010      WD
# 1            0    NaN   NaN         NaN        0       2    2009      WD
# 2            0    NaN   NaN         NaN        0       2    2009      WD
# 3            0    NaN   NaN         NaN        0      11    2007      WD
# 4            0    NaN   NaN         NaN        0       5    2009      WD
# ...        ...    ...   ...         ...      ...     ...     ...      ...
# 2599         0    NaN   NaN         NaN        0       5    2009      WD
# 2600         0    NaN   NaN         NaN        0       6    2009      WD
# 2601         0    NaN   NaN         NaN        0       8    2007      WD
# 2602         0    NaN   NaN         NaN        0       7    2007      WD
# 2603         0    NaN   NaN         NaN        0       9    2006      WD
#
#      SaleCondition                       Prop_Addr   latitude  longitude
# 0           Normal      436 HAYWARD AVE, Ames, USA  42.018564 -93.651619
# 1           Normal         3416 WEST ST, Ames, USA  42.024855 -93.663671
# 2           Normal         3416 WEST ST, Ames, USA  42.024855 -93.663671
# 3           Normal         320 S 2ND ST, Ames, USA  42.021548 -93.614068
# 4           Normal     1524 DOUGLAS AVE, Ames, USA  42.037391 -93.612207
# ...            ...                             ...        ...        ...
# 2599        Normal   1021 RIDGEWOOD AVE, Ames, USA  42.032102 -93.626373
# 2600        Normal        3619 MARY CIR, Ames, USA  42.027669 -93.666138
# 2601        Normal  2140 SUNSET DR 2142, Ames, USA  42.020129 -93.643832
# 2602        Normal    5319 CLEMENS BLVD, Ames, USA  42.016802 -93.689748
# 2603        Normal      1025 VERMONT CT, Ames, USA  42.030997 -93.682220
#
# [2604 rows x 84 columns]

# %%
sales = pd.DataFrame({
    'Date': housing['MoSold'].astype(str) + '-' + housing['YrSold'].astype(str),
    'SalePrice': housing['SalePrice'],
    'TotalSF': housing['GrLivArea'] + housing['TotalBsmtSF']
})

# %%
sales
# Out:
#          Date  SalePrice  TotalSF
# 0      3-2010     126000   1712.0
# 1      2-2009     139500   2098.0
# 2      2-2009     139500   2098.0
# 3     11-2007     124900   1838.0
# 4      5-2009     114000   1444.0
# ...       ...        ...      ...
# 2599   5-2009     121000   1904.0
# 2600   6-2009     139600   1733.0
# 2601   8-2007     145000   3003.0
# 2602   7-2007     217500   2827.0
# 2603   9-2006     215000   2688.0
#
# [2604 rows x 3 columns]

# %%
# calculate price per square foot
sales['PricePerSF'] = sales['SalePrice'] / sales['TotalSF']

# group by year and calculate average price per square foot for each year
yearly_avg_ppsf = sales.groupby('Date')['PricePerSF'].mean()

# calculate percentage change in average price per square foot from the previous year
pct_change_ppsf = yearly_avg_ppsf.pct_change()

print(pct_change_ppsf)
# Out:
# Date
# 1-2006          NaN
# 1-2007     0.073860
# 1-2008    -0.055408
# 1-2009     0.086399
# 1-2010    -0.030927
# 10-2006   -0.111088
# 10-2007    0.161515
# 10-2008   -0.079370
# 10-2009    0.016534
# 11-2006   -0.000018
# 11-2007   -0.043911
# 11-2008   -0.010226
# 11-2009    0.040516
# 12-2006    0.029891
# 12-2007    0.057299
# 12-2008   -0.061765
# 12-2009   -0.096211
# 2-2006     0.113535
# 2-2007    -0.085960
# 2-2008     0.160041
# 2-2009    -0.093028
# 2-2010     0.019290
# 3-2006    -0.012171
# 3-2007     0.008494
# 3-2008    -0.003441
# 3-2009     0.020525
# 3-2010    -0.041447
# 4-2006    -0.005590
# 4-2007    -0.012590
# 4-2008     0.052234
# 4-2009     0.036844
# 4-2010     0.006285
# 5-2006    -0.060075
# 5-2007     0.035338
# 5-2008     0.007022
# 5-2009    -0.001699
# 5-2010    -0.038336
# 6-2006     0.046576
# 6-2007    -0.002802
# 6-2008    -0.010446
# 6-2009     0.010585
# 6-2010    -0.032808
# 7-2006     0.038657
# 7-2007    -0.000932
# 7-2008    -0.012237
# 7-2009     0.050636
# 7-2010    -0.169691
# 8-2006     0.174071
# 8-2007    -0.019028
# 8-2008     0.009901
# 8-2009    -0.047422
# 9-2006     0.089906
# 9-2007    -0.123848
# 9-2008     0.061769
# 9-2009     0.009487
# Name: PricePerSF, dtype: float64

# %%
# calculate price per square foot
sales['PricePerSF'] = sales['SalePrice'] / sales['TotalSF']

# extract year from the Date column and group by year
sales['Year'] = sales['Date'].str[-4:]
yearly_avg_ppsf = sales.groupby('Year')['PricePerSF'].mean()

# calculate percentage change in average price per square foot from the previous year
pct_change_ppsf = yearly_avg_ppsf.pct_change()

print(pct_change_ppsf)
# Out:
# Year
# 2006         NaN
# 2007    0.005405
# 2008   -0.000078
# 2009    0.007665
# 2010   -0.020993
# Name: PricePerSF, dtype: float64

# %%
# calculate price per square foot
sales['PricePerSF'] = sales['SalePrice'] / sales['TotalSF']

# extract year from the Date column and group by year
sales['Year'] = sales['Date'].str[-4:]
yearly_avg_ppsf = sales.groupby('Year')['PricePerSF'].mean()

print(yearly_avg_ppsf)
# Out:
# Year
# 2006    69.828042
# 2007    70.205431
# 2008    70.199930
# 2009    70.737978
# 2010    69.252959
# Name: PricePerSF, dtype: float64

# %%
# calculate price per square foot
sales['PricePerSF'] = sales['SalePrice'] / sales['TotalSF']

# extract year from the Date column and group by year
sales['Year'] = sales['Date'].str[-4:]

# sort by TotalSF and remove the 5 largest rows
sales_sorted = sales.sort_values('TotalSF', ascending=False)
sales_sorted = sales_sorted.iloc[5:]

# calculate average sale price per year
yearly_avg_price = sales_sorted.groupby('Year')['SalePrice'].mean()

print(yearly_avg_price)
# Out:
# Year
# 2006    175574.367113
# 2007    176731.387043
# 2008    177895.141844
# 2009    181880.309645
# 2010    172703.996865
# Name: SalePrice, dtype: float64

# %%
# Compute the percentage change in SalePrice from the previous year
housing["PriceChange"] = housing.groupby("YrSold")["SalePrice"].apply(
    lambda x: x.pct_change()
)

# Create a new dataframe without the 5 largest GrLivArea values
new_housing = housing.sort_values("GrLivArea", ascending=False).iloc[5:]

# Compute the average sale price by year
avg_price_by_year = new_housing.groupby("YrSold")["SalePrice"].mean()

# Create a matrix X with the feature(s) you want to test for significance
X = new_housing[["GrLivArea"]]
y = avg_price_by_year

# Fit the OLS model and print the summary
X = sm.add_constant(X)
model = sm.OLS(y, X, missing="drop").fit()
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 16>()
#      14 # Fit the OLS model and print the summary
#      15 X = sm.add_constant(X)
# ---> 16 model = sm.OLS(y, X, missing='drop').fit()
#      17 print(model.summary())
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:890, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     887     msg = ("Weights are not supported in OLS and will be ignored"
#     888            "An exception will be raised in the next version.")
#     889     warnings.warn(msg, ValueWarning)
# --> 890 super(OLS, self).__init__(endog, exog, missing=missing,
#     891                           hasconst=hasconst, **kwargs)
#     892 if "weights" in self._init_keys:
#     893     self._init_keys.remove("weights")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:717, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     715 else:
#     716     weights = weights.squeeze()
# --> 717 super(WLS, self).__init__(endog, exog, missing=missing,
#     718                           weights=weights, hasconst=hasconst, **kwargs)
#     719 nobs = self.exog.shape[0]
#     720 weights = self.weights
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:191, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     190 def __init__(self, endog, exog, **kwargs):
# --> 191     super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     192     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:267, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     266 def __init__(self, endog, exog=None, **kwargs):
# --> 267     super().__init__(endog, exog, **kwargs)
#     268     self.initialize()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:92, in Model.__init__(self, endog, exog, **kwargs)
#      90 missing = kwargs.pop('missing', 'none')
#      91 hasconst = kwargs.pop('hasconst', None)
# ---> 92 self.data = self._handle_data(endog, exog, missing, hasconst,
#      93                               **kwargs)
#      94 self.k_constant = self.data.k_constant
#      95 self.exog = self.data.exog
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:132, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     131 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 132     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     133     # kwargs arrays could have changed, easier to just attach here
#     134     for key in kwargs:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/data.py:673, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670     exog = np.asarray(exog)
#     672 klass = handle_data_class_factory(endog, exog)
# --> 673 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     674              **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/data.py:70, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      68     self.formula = kwargs.pop('formula')
#      69 if missing != 'none':
# ---> 70     arrays, nan_idx = self.handle_missing(endog, exog, missing,
#      71                                           **kwargs)
#      72     self.missing_row_idx = nan_idx
#      73     self.__dict__.update(arrays)  # attach all the data arrays
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/data.py:264, in ModelData.handle_missing(cls, endog, exog, missing, **kwargs)
#     261         nan_mask |= combined_2d_nans
#     263 else:
# --> 264     nan_mask = _nan_rows(*combined)
#     265     if combined_2d:
#     266         nan_mask = _nan_rows(*(nan_mask[:, None],) + combined_2d)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/data.py:49, in _nan_rows(*arrs)
#      46     x_is_boolean_array = hasattr(x, 'dtype') and x.dtype == bool and x
#      47     return np.logical_or(_asarray_2d_null_rows(x),
#      48                          (x_is_boolean_array | _asarray_2d_null_rows(y)))
# ---> 49 return reduce(_nan_row_maybe_two_inputs, arrs).squeeze()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/data.py:47, in _nan_rows.<locals>._nan_row_maybe_two_inputs(x, y)
#      44 def _nan_row_maybe_two_inputs(x, y):
#      45     # check for dtype bc dataframe has dtypes
#      46     x_is_boolean_array = hasattr(x, 'dtype') and x.dtype == bool and x
# ---> 47     return np.logical_or(_asarray_2d_null_rows(x),
#      48                          (x_is_boolean_array | _asarray_2d_null_rows(y)))
#
# ValueError: operands could not be broadcast together with shapes (5,1) (2599,1)

# %%
housing
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 0     909176150        856     126000          30       RL          NaN
# 1     905476230       1049     139500         120       RL         42.0
# 2     905476230       1049     139500         120       RL         42.0
# 3     911128020       1001     124900          30  C (all)         60.0
# 4     535377150       1039     114000          70       RL         80.0
# ...         ...        ...        ...         ...      ...          ...
# 2599  903205040        952     121000          30       RL          NaN
# 2600  905402060       1733     139600          20       RL          NaN
# 2601  909275030       2002     145000          90       RH         82.0
# 2602  907192040       1842     217500          60       RL          NaN
# 2603  906223180       1911     215000          60       RL         80.0
#
#       LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0        7890   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 1        4235   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2        4235   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 3        6060   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 4        8146   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 2599     8854   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2600    13680   Pave   NaN      IR1         Lvl    AllPub   CulDSac       Gtl
# 2601     6270   Pave   NaN      Reg         HLS    AllPub    Inside       Gtl
# 2602     8826   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2603     9554   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 0           SWISU       Norm       Norm     1Fam     1Story            6
# 1         Edwards       Norm       Norm   TwnhsE     1Story            5
# 2         Edwards       Norm       Norm   TwnhsE     1Story            5
# 3          IDOTRR       Norm       Norm     1Fam     1Story            5
# 4         OldTown       Norm       Norm     1Fam     2Story            4
# ...           ...        ...        ...      ...        ...          ...
# 2599      BrkSide       Norm       Norm     1Fam     1.5Unf            6
# 2600      Edwards       Norm       Norm     1Fam     1Story            3
# 2601      Crawfor       Norm       Norm   Duplex     2Story            5
# 2602      CollgCr       Norm       Norm     1Fam     2Story            7
# 2603      SawyerW       Norm       Norm     1Fam     2Story            8
#
#       OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 0               6       1939          1950     Gable  CompShg     Wd Sdng
# 1               5       1984          1984     Gable  CompShg     HdBoard
# 2               5       1984          1984     Gable  CompShg     HdBoard
# 3               9       1930          2007       Hip  CompShg     MetalSd
# 4               8       1900          2003     Gable  CompShg     MetalSd
# ...           ...        ...           ...       ...      ...         ...
# 2599            6       1916          1950     Gable  CompShg     Wd Sdng
# 2600            5       1955          1955       Hip  CompShg     BrkFace
# 2601            6       1949          1950     Gable  CompShg     MetalSd
# 2602            5       2000          2000     Gable  CompShg     VinylSd
# 2603            5       1993          1994     Gable  CompShg     VinylSd
#
#      Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation  \
# 0        Wd Sdng       None         0.0        TA        TA     CBlock
# 1        HdBoard    BrkFace       149.0        Gd        TA     CBlock
# 2        HdBoard    BrkFace       149.0        Gd        TA     CBlock
# 3        MetalSd       None         0.0        Gd        TA     BrkTil
# 4        MetalSd       None         0.0        Gd        Gd     BrkTil
# ...          ...        ...         ...       ...       ...        ...
# 2599     Wd Sdng       None         0.0        TA        TA     BrkTil
# 2600     Wd Sdng       None         0.0        TA        TA       Slab
# 2601     MetalSd       None         0.0        TA        TA     CBlock
# 2602     VinylSd    BrkFace       144.0        Gd        TA      PConc
# 2603     VinylSd    BrkFace       125.0        Gd        TA      PConc
#
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 0          TA       TA           No          Rec       238.0          Unf
# 1          Gd       TA           Mn          GLQ       552.0          ALQ
# 2          Gd       TA           Mn          GLQ       552.0          ALQ
# 3          TA       TA           No          ALQ       737.0          Unf
# 4          Fa       TA           No          Unf         0.0          Unf
# ...       ...      ...          ...          ...         ...          ...
# 2599       TA       TA           No          Unf         0.0          Unf
# 2600      NaN      NaN          NaN          NaN         0.0          NaN
# 2601       TA       TA           No          BLQ       284.0          Unf
# 2602       Gd       TA           No          GLQ       841.0          Unf
# 2603       Gd       TA           No          GLQ       380.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# 0            0.0      618.0        856.0    GasA        TA          Y
# 1          393.0      104.0       1049.0    GasA        TA          Y
# 2          393.0      104.0       1049.0    GasA        TA          Y
# 3            0.0      100.0        837.0    GasA        Ex          Y
# 4            0.0      405.0        405.0    GasA        Gd          Y
# ...          ...        ...          ...     ...       ...        ...
# 2599         0.0      952.0        952.0    Grav        Fa          N
# 2600         0.0        0.0          0.0    GasA        Ex          Y
# 2601         0.0      717.0       1001.0    GasA        TA          N
# 2602         0.0      144.0        985.0    GasA        Ex          Y
# 2603         0.0      397.0        777.0    GasA        Ex          Y
#
#      Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  \
# 0         SBrkr       856         0             0           1.0           0.0
# 1         SBrkr      1049         0             0           1.0           0.0
# 2         SBrkr      1049         0             0           1.0           0.0
# 3         SBrkr      1001         0             0           0.0           0.0
# 4         SBrkr       717       322             0           0.0           0.0
# ...         ...       ...       ...           ...           ...           ...
# 2599      FuseF       952         0             0           0.0           0.0
# 2600      FuseA      1733         0             0           0.0           0.0
# 2601      FuseA      1001      1001             0           0.0           0.0
# 2602      SBrkr       985       857             0           1.0           0.0
# 2603      SBrkr      1065       846             0           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            1         0             2             1          TA
# 1            2         0             2             1          Gd
# 2            2         0             2             1          Gd
# 3            1         0             2             1          Gd
# 4            1         0             2             1          TA
# ...        ...       ...           ...           ...         ...
# 2599         1         0             2             1          Fa
# 2600         2         0             4             1          TA
# 2601         2         0             4             2          TA
# 2602         2         1             3             1          Gd
# 2603         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                4        Typ           1          Gd     Detchd       1939.0
# 1                5        Typ           0         NaN     Attchd       1984.0
# 2                5        Typ           0         NaN     Attchd       1984.0
# 3                5        Typ           0         NaN     Detchd       1930.0
# 4                6        Typ           0         NaN     Detchd       1940.0
# ...            ...        ...         ...         ...        ...          ...
# 2599             4        Typ           1          Gd     Detchd       1916.0
# 2600             8       Min2           1          Gd     Attchd       1955.0
# 2601             8        Typ           0         NaN     2Types       1949.0
# 2602             7        Typ           1          TA     Attchd       2000.0
# 2603             8        Typ           1          TA     Attchd       1993.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             Unf         2.0       399.0         TA         TA          Y
# 1             Fin         1.0       266.0         TA         TA          Y
# 2             Fin         1.0       266.0         TA         TA          Y
# 3             Unf         1.0       216.0         TA         Po          N
# 4             Unf         1.0       281.0         TA         TA          N
# ...           ...         ...         ...        ...        ...        ...
# 2599          Unf         1.0       192.0         Fa         Po          P
# 2600          Unf         2.0       452.0         TA         TA          Y
# 2601          Unf         3.0       871.0         TA         TA          Y
# 2602          Fin         2.0       486.0         TA         TA          Y
# 2603          RFn         2.0       471.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0            0              0          0          166
# 1              0          105              0          0            0
# 2              0          105              0          0            0
# 3            154            0             42         86            0
# 4              0            0            168          0          111
# ...          ...          ...            ...        ...          ...
# 2599           0           98              0          0           40
# 2600           0            0              0          0            0
# 2601           0            0              0          0            0
# 2602         193           96              0          0            0
# 2603         182           81              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN   NaN         NaN        0       3    2010      WD
# 1            0    NaN   NaN         NaN        0       2    2009      WD
# 2            0    NaN   NaN         NaN        0       2    2009      WD
# 3            0    NaN   NaN         NaN        0      11    2007      WD
# 4            0    NaN   NaN         NaN        0       5    2009      WD
# ...        ...    ...   ...         ...      ...     ...     ...      ...
# 2599         0    NaN   NaN         NaN        0       5    2009      WD
# 2600         0    NaN   NaN         NaN        0       6    2009      WD
# 2601         0    NaN   NaN         NaN        0       8    2007      WD
# 2602         0    NaN   NaN         NaN        0       7    2007      WD
# 2603         0    NaN   NaN         NaN        0       9    2006      WD
#
#      SaleCondition                       Prop_Addr   latitude  longitude  \
# 0           Normal      436 HAYWARD AVE, Ames, USA  42.018564 -93.651619
# 1           Normal         3416 WEST ST, Ames, USA  42.024855 -93.663671
# 2           Normal         3416 WEST ST, Ames, USA  42.024855 -93.663671
# 3           Normal         320 S 2ND ST, Ames, USA  42.021548 -93.614068
# 4           Normal     1524 DOUGLAS AVE, Ames, USA  42.037391 -93.612207
# ...            ...                             ...        ...        ...
# 2599        Normal   1021 RIDGEWOOD AVE, Ames, USA  42.032102 -93.626373
# 2600        Normal        3619 MARY CIR, Ames, USA  42.027669 -93.666138
# 2601        Normal  2140 SUNSET DR 2142, Ames, USA  42.020129 -93.643832
# 2602        Normal    5319 CLEMENS BLVD, Ames, USA  42.016802 -93.689748
# 2603        Normal      1025 VERMONT CT, Ames, USA  42.030997 -93.682220
#
#       PriceChange
# 0             NaN
# 1             NaN
# 2        0.000000
# 3             NaN
# 4       -0.182796
# ...           ...
# 2599    -0.324022
# 2600     0.153719
# 2601     0.319381
# 2602     0.500000
# 2603     0.094148
#
# [2604 rows x 85 columns]

# %%
# Filter data for years 2006-2010
housing_years = housing[housing["YrSold"].between(2006, 2010)]

# Group data by number of bedrooms (Rooms column) and calculate the mean price for each group
mean_prices_by_rooms = housing_years.groupby("Rooms")["SalePrice"].mean()

# Print the result
print(mean_prices_by_rooms)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 5>()
#       2 housing_years = housing[housing['YrSold'].between(2006, 2010)]
#       4 # Group data by number of bedrooms (Rooms column) and calculate the mean price for each group
# ----> 5 mean_prices_by_rooms = housing_years.groupby('Rooms')['SalePrice'].mean()
#       7 # Print the result
#       8 print(mean_prices_by_rooms)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
#    7722     dropna=dropna,
#    7723 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/grouper.py:882, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     880         in_axis, level, gpr = False, gpr, None
#     881     else:
# --> 882         raise KeyError(gpr)
#     883 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     884     # Add key to exclusions
#     885     exclusions.add(gpr.key)
#
# KeyError: 'Rooms'

# %%
# Prepare data
X = housing[['BedroomAbvGr', 'Distance', 'Bathroom', 'Landsize', 'latitude', 'longitude']]
y = housing['PriceChange']

# Drop rows with missing values
X = X.dropna()
y = y[X.index]

# Group data by number of bedrooms and year
data = housing[['BedroomAbvGr', 'YrSold', 'PriceChange']]
data = data.groupby(['BedroomAbvGr', 'YrSold']).mean()

# Pivot the data and fill missing values with 0
data = data.pivot_table(values='PriceChange', index='BedroomAbvGr', columns='YrSold', fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 # Prepare data
# ----> 2 X = housing[['BedroomAbvGr', 'Distance', 'Bathroom', 'Landsize', 'latitude', 'longitude']]
#       3 y = housing['PriceChange']
#       5 # Drop rows with missing values
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Distance', 'Bathroom', 'Landsize'] not in index"

# %%
housing.columns
# Out:
# Index(['PID', 'GrLivArea', 'SalePrice', 'MSSubClass', 'MSZoning',
#        'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'Prop_Addr', 'latitude', 'longitude', 'PriceChange'],
#       dtype='object')

# %%
for i in range(1, 4):
    col_name = f'BedroomAbvGr_{i}'
    filtered_data = housing.loc[housing['BedroomAbvGr'] == i, ['SalePrice', 'YrSold']]
    if not filtered_data.empty:
        avg_price = filtered_data.groupby('YrSold').mean()
        print(f"Average price for {i} bedroom(s) in each year:\n{avg_price}\n")
# Out:
# Average price for 1 bedroom(s) in each year:
#             SalePrice
# YrSold
# 2006    149520.550000
# 2007    188108.952381
# 2008    183832.608696
# 2009    154900.000000
# 2010    210285.538462
#
# Average price for 2 bedroom(s) in each year:
#             SalePrice
# YrSold
# 2006    159227.260274
# 2007    162915.680272
# 2008    159398.669014
# 2009    166412.858065
# 2010    150621.012500
#
# Average price for 3 bedroom(s) in each year:
#             SalePrice
# YrSold
# 2006    172782.366038
# 2007    172942.637427
# 2008    176055.336735
# 2009    186847.632653
# 2010    172689.794286

# %%
for i in range(1, 4):
    col_name = f'BedroomAbvGr_{i}'
    filtered_data = housing.loc[housing['BedroomAbvGr'] == i, ['SalePrice', 'YrSold']]
    if not filtered_data.empty:
        avg_price = filtered_data.groupby('YrSold').mean()
        print(f"Average price for {i} bedroom(s) in each year:\n{avg_price}\n")
        sold_count = filtered_data.groupby('YrSold').size()
        print(f"Number of houses sold with {i} bedroom(s) in each year:\n{sold_count}\n")
# Out:
# Average price for 1 bedroom(s) in each year:
#             SalePrice
# YrSold
# 2006    149520.550000
# 2007    188108.952381
# 2008    183832.608696
# 2009    154900.000000
# 2010    210285.538462
#
# Number of houses sold with 1 bedroom(s) in each year:
# YrSold
# 2006    20
# 2007    21
# 2008    23
# 2009    20
# 2010    13
# dtype: int64
#
# Average price for 2 bedroom(s) in each year:
#             SalePrice
# YrSold
# 2006    159227.260274
# 2007    162915.680272
# 2008    159398.669014
# 2009    166412.858065
# 2010    150621.012500
#
# Number of houses sold with 2 bedroom(s) in each year:
# YrSold
# 2006    146
# 2007    147
# 2008    142
# 2009    155
# 2010     80
# dtype: int64
#
# Average price for 3 bedroom(s) in each year:
#             SalePrice
# YrSold
# 2006    172782.366038
# 2007    172942.637427
# 2008    176055.336735
# 2009    186847.632653
# 2010    172689.794286
#
# Number of houses sold with 3 bedroom(s) in each year:
# YrSold
# 2006    265
# 2007    342
# 2008    294
# 2009    343
# 2010    175
# dtype: int64

# %%
import numpy as np

for i in range(1, 4):
    col_name = f'BedroomAbvGr_{i}'
    filtered_data = housing.loc[housing['BedroomAbvGr'] == i, ['SalePrice', 'YrSold']]
    if not filtered_data.empty:
        filtered_data['SalePrice'] = np.ceil(filtered_data['SalePrice'])
        avg_price = filtered_data.groupby('YrSold').mean()
        print(f"Average price for {i} bedroom(s) in each year (rounded up to the nearest whole number):\n{avg_price}\n")
# Out:
# Average price for 1 bedroom(s) in each year (rounded up to the nearest whole number):
#             SalePrice
# YrSold
# 2006    149520.550000
# 2007    188108.952381
# 2008    183832.608696
# 2009    154900.000000
# 2010    210285.538462
#
# Average price for 2 bedroom(s) in each year (rounded up to the nearest whole number):
#             SalePrice
# YrSold
# 2006    159227.260274
# 2007    162915.680272
# 2008    159398.669014
# 2009    166412.858065
# 2010    150621.012500
#
# Average price for 3 bedroom(s) in each year (rounded up to the nearest whole number):
#             SalePrice
# YrSold
# 2006    172782.366038
# 2007    172942.637427
# 2008    176055.336735
# 2009    186847.632653
# 2010    172689.794286

# %%
for i in range(1, 4):
    col_name = f'BedroomAbvGr_{i}'
    filtered_data = housing.loc[housing['BedroomAbvGr'] == i, ['SalePrice', 'YrSold']]
    if not filtered_data.empty:
        avg_price = filtered_data.groupby('YrSold').mean().astype(int)
        print(f"Average price for {i} bedroom(s) in each year:\n{avg_price}\n")
        sold_count = filtered_data.groupby('YrSold').size()
        print(f"Number of houses sold with {i} bedroom(s) in each year:\n{sold_count}\n")
# Out:
# Average price for 1 bedroom(s) in each year:
#         SalePrice
# YrSold
# 2006       149520
# 2007       188108
# 2008       183832
# 2009       154900
# 2010       210285
#
# Number of houses sold with 1 bedroom(s) in each year:
# YrSold
# 2006    20
# 2007    21
# 2008    23
# 2009    20
# 2010    13
# dtype: int64
#
# Average price for 2 bedroom(s) in each year:
#         SalePrice
# YrSold
# 2006       159227
# 2007       162915
# 2008       159398
# 2009       166412
# 2010       150621
#
# Number of houses sold with 2 bedroom(s) in each year:
# YrSold
# 2006    146
# 2007    147
# 2008    142
# 2009    155
# 2010     80
# dtype: int64
#
# Average price for 3 bedroom(s) in each year:
#         SalePrice
# YrSold
# 2006       172782
# 2007       172942
# 2008       176055
# 2009       186847
# 2010       172689
#
# Number of houses sold with 3 bedroom(s) in each year:
# YrSold
# 2006    265
# 2007    342
# 2008    294
# 2009    343
# 2010    175
# dtype: int64
